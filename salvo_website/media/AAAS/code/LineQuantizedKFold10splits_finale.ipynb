# %% [markdown]
# ***TITLE: FN-NET LIGHTWEIGHT CNN MODEL FOR FABRIC DEFECT DETECTION***

# %% [markdown]
# ***IMPORT LIBRARIES***

# %%
# %%


import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.model_selection import StratifiedKFold
# Out:
# 2025-08-07 09:38:34.522815: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-07 09:38:34.673654: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754559514.726515     406 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754559514.742615     406 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-07 09:38:34.867952: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import matplotlib.pyplot as plt
import cv2
import shutil
import numpy as np


import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ***DATA PREPROCESSING***
#
# **1)** **DATASET IMPORTING**

# %%
from tensorflow.keras.utils import Sequence
from glob import glob
import cv2
import numpy as np
import os

class CustomDataGenerator(Sequence):
    def __init__(self, image_paths, labels, batch_size, img_size, num_classes, shuffle=True, class_indices=None):
        self.image_paths = image_paths
        self.labels = labels
        self.classes = np.array(labels)
        self.batch_size = batch_size
        self.img_size = img_size
        self.num_classes = num_classes
        self.shuffle = shuffle
        self.class_indices = class_indices or self._build_class_indices(labels)
        self.on_epoch_end()
        self.current_index=0
        
    def __iter__(self):
        """Initialize the iterator."""
        self.current_index = 0
        return self

    def __next__(self):
        """Get the next batch."""
        if self.current_index >= len(self):
            # End of epoch
            self.on_epoch_end()
            self.current_index = 0
            raise StopIteration
        
        batch = self.__getitem__(self.current_index)
        self.current_index += 1
        return batch
    
    
    def reset(self):
        """Reset the generator for the next epoch."""
        self.current_index = 0
        if self.shuffle:
            combined = list(zip(self.image_paths, self.labels))
            np.random.shuffle(combined)
            self.image_paths, self.labels = map(list, zip(*combined))  # Convert back to lists
            self.classes = np.array(self.labels)  # Update classes array as well
    
    def _build_class_indices(self, labels):
        unique_labels = sorted(set(labels))
        return {str(lbl): lbl for lbl in unique_labels}

    def __len__(self):
        return int(np.ceil(len(self.image_paths) / self.batch_size))

    def __getitem__(self, idx):
        batch_paths = self.image_paths[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch_labels = self.labels[idx * self.batch_size:(idx + 1) * self.batch_size]

        batch_images = []
        for path in batch_paths:
            img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, self.img_size)
            img = img.astype(np.float32) / 255.0
            stacked =np.stack([img], axis=-1)
            batch_images.append(stacked)

        batch_images = np.array(batch_images)
        batch_labels = tf.keras.utils.to_categorical(batch_labels, self.num_classes)

        return batch_images, batch_labels

    def on_epoch_end(self):
        if self.shuffle:
            combined = list(zip(self.image_paths, self.labels))
            np.random.shuffle(combined)
            self.image_paths, self.labels = map(list, zip(*combined))  # Convert back to lists
            self.classes = np.array(self.labels)  # Update classes array as well

# %%
# %%
train_dir = "/mnt/c/newTrainHV/Train"

test_dir = "/mnt/c/newTrainHV/Test"

# %%
from sklearn.preprocessing import LabelEncoder

def get_filepaths_and_labels(directory):
    class_names = sorted(os.listdir(directory))
    filepaths = []
    labels = []

    for idx, class_name in enumerate(class_names):
        class_dir = os.path.join(directory, class_name)
        if not os.path.isdir(class_dir):
            continue
        for fname in glob(os.path.join(class_dir, "*")):
            filepaths.append(fname)
            labels.append(class_name)

    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(labels)
    class_indices = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
    return filepaths, encoded_labels, len(label_encoder.classes_), label_encoder,class_indices
# Image parameters
IMG_SIZE = (256,256 )  # Image size
BATCH_SIZE = 40       # Number of images in each batch
# Train

train_filepaths, train_labels, NUM_CLASSES, label_encoder,class_indices = get_filepaths_and_labels(train_dir)
test_filepaths, test_labels, _, _,_ = get_filepaths_and_labels(test_dir)

# Combine for full dataset cross-validation
all_filepaths = np.array(train_filepaths + test_filepaths)
all_labels = np.array(train_labels.tolist() + test_labels.tolist())

from sklearn.model_selection import train_test_split

# Split the combined data into 95% train set and 5% final test set
X_train_main, X_test_final, y_train_main, y_test_final = train_test_split(
    all_filepaths,
    all_labels,
    test_size=0.05,
    stratify=all_labels,  # Maintain class balance
    random_state=42
)

train_generator = CustomDataGenerator(X_train_main, y_train_main, BATCH_SIZE, IMG_SIZE, NUM_CLASSES,class_indices=class_indices)
test_generator = CustomDataGenerator( X_test_final, y_test_final, BATCH_SIZE, IMG_SIZE, NUM_CLASSES, shuffle=False,class_indices=class_indices)

# %% [markdown]
# **2) DATASET STATISTICS AND VISUALIZATION**

# %%
# %%
train_set= train_generator
test_set= test_generator
print("Class Indices:", train_set.class_indices)
print("Number of Classes:", train_set.num_classes)
print("Number of Classes:", test_set.num_classes)
from collections import Counter
print(Counter(train_set.classes))
print(Counter(test_set.classes))
# Out:
# Class Indices: {'No_Defect': 0, 'horizontal_line': 1, 'stain': 2, 'tear': 3, 'vertical_line': 4}
# Number of Classes: 5
# Number of Classes: 5
# Counter({3: 1341, 0: 1333, 1: 646, 4: 639, 2: 601})
# Counter({3: 71, 0: 70, 1: 34, 4: 33, 2: 32})

# %% [markdown]
# ***MODEL CREATION***

# %%
# Parameters
INPUT_SHAPE = (256, 256, 1)  # Input size of images
NUM_CLASSES =  train_generator.num_classes             # many class
LEARNING_RATE = 0.001
EPOCHS = 100                 # Increased epochs
BATCH_SIZE = 40

# %%
from keras.saving import register_keras_serializable
from tensorflow.keras.layers import Layer
import tensorflow as tf

@register_keras_serializable()
class SimAM(Layer):
    def __init__(self, e_lambda=1e-4, **kwargs):
        super(SimAM, self).__init__(**kwargs)
        self.e_lambda = e_lambda

    def call(self, x):
        mean = tf.reduce_mean(x, axis=[1, 2], keepdims=True)
        var = tf.reduce_mean(tf.square(x - mean), axis=[1, 2], keepdims=True)
        attention = tf.sigmoid((x - mean) / tf.sqrt(var + self.e_lambda))
        return x * attention

# %%
import tensorflow as tf

# Define quantization functions
def fake_quantize(x, bits=8, min_value=None, max_value=None):
    if min_value is None:
        min_value = tf.reduce_min(x)
    if max_value is None:
        max_value = tf.reduce_max(x)
    
    # Ensure min doesn't equal max to prevent division by zero
    max_value = tf.maximum(max_value, min_value + 1e-6)
    
    # Calculate the step size (the value of 1 bit)
    step = (max_value - min_value) / (2**bits - 1)
    
    # Quantize the values
    x_int = tf.round((x - min_value) / step)
    
    # Clip values to the quantization range
    x_int = tf.clip_by_value(x_int, 0, 2**bits - 1)
    
    # Convert back to original range
    x_q = x_int * step + min_value
    
    # During training, pass through the gradients using STE (Straight Through Estimator)
    return x + tf.stop_gradient(x_q - x)

@tf.keras.utils.register_keras_serializable()
class QuantizedConv2D(tf.keras.layers.Layer):
    def __init__(self, filters, kernel_size, padding='same', strides=1, activation=None, weight_bits=8, activation_bits=8, **kwargs):
        super(QuantizedConv2D, self).__init__(**kwargs)
        self.filters = int(filters)
        # Ensure kernel_size is stored as a tuple of integers
        if isinstance(kernel_size, int):
            self.kernel_size = (int(kernel_size), int(kernel_size))
        else:
            self.kernel_size = (int(kernel_size[0]), int(kernel_size[1]))
        self.padding = padding
        if isinstance(strides, int):
            self.strides = (int(strides), int(strides))
        else:
            self.strides = (int(strides[0]), int(strides[1]))
        self.activation_fn = tf.keras.activations.get(activation)
        self.weight_bits = int(weight_bits)
        self.activation_bits = int(activation_bits)
        
    def build(self, input_shape):
        input_channels = int(input_shape[-1])
        kernel_size = tuple(self.kernel_size)
        kernel_shape = kernel_shape = (
            int(self.kernel_size[0]),
            int(self.kernel_size[1]),
            int(input_channels),
            int(self.filters)
            )
        self.kernel = self.add_weight(
            name='kernel',
            shape=kernel_shape,
            initializer='glorot_uniform',
            trainable=True
        )
        
        self.bias = self.add_weight(
            name='bias',
            shape=(self.filters,),
            initializer='zeros',
            trainable=True
        )
        
        # Track min and max values for weights (needed for quantization)
        self.w_min = self.add_weight(
            name='w_min',
            shape=(1,),
            initializer=tf.constant_initializer(-1.0),
            trainable=False
        )
        
        self.w_max = self.add_weight(
            name='w_max',
            shape=(1,),
            initializer=tf.constant_initializer(1.0),
            trainable=False
        )
        
        # Track min and max values for activations
        self.a_min = self.add_weight(
            name='a_min',
            shape=(1,),
            initializer=tf.constant_initializer(0.0),
            trainable=False
        )
        
        self.a_max = self.add_weight(
            name='a_max',
            shape=(1,),
            initializer=tf.constant_initializer(6.0),  # ReLU typically has max around 6
            trainable=False
        )
        
        self.built = True
    
    def call(self, inputs, training=None):
        if training:
            curr_w_min = tf.reduce_min(self.kernel)
            curr_w_max = tf.reduce_max(self.kernel)
            
            # Use EMA (Exponential Moving Average) to update min/max values
            momentum = 0.9
            self.w_min.assign(momentum * self.w_min + (1 - momentum) * curr_w_min)
            self.w_max.assign(momentum * self.w_max + (1 - momentum) * curr_w_max)
        
        # Quantize weights
        quantized_kernel = fake_quantize(
            self.kernel, 
            bits=self.weight_bits,
            min_value=self.w_min,
            max_value=self.w_max
        )
        
        # Standard convolution with quantized weights
        outputs = tf.nn.conv2d(
            inputs,
            quantized_kernel,
            strides=[1, self.strides[0], self.strides[1], 1],
            padding=self.padding.upper()
        )
        
        outputs = tf.nn.bias_add(outputs, self.bias)
        
        # Apply activation if specified
        if self.activation_fn is not None:
            outputs = self.activation_fn(outputs)
            
            # Update activation min/max during training
            if training:
                curr_a_min = tf.reduce_min(outputs)
                curr_a_max = tf.reduce_max(outputs)
                
                # Use EMA to update min/max values
                momentum = 0.9
                self.a_min.assign(momentum * self.a_min + (1 - momentum) * curr_a_min)
                self.a_max.assign(momentum * self.a_max + (1 - momentum) * curr_a_max)
            
            # Quantize activations
            outputs = fake_quantize(
                outputs,
                bits=self.activation_bits,
                min_value=self.a_min,
                max_value=self.a_max
            )
        
        return outputs

    def get_config(self):
        config = super(QuantizedConv2D, self).get_config()
        config.update({
            'filters': int(self.filters),  # Ensure filters is serialized as int
            'kernel_size': (int(self.kernel_size[0]), int(self.kernel_size[1])),  # Ensure tuple of ints
            'padding': self.padding,
            'strides': (int(self.strides[0]), int(self.strides[1])),  # Ensure tuple of ints
            'activation': tf.keras.activations.serialize(self.activation_fn),
            'weight_bits': int(self.weight_bits),
            'activation_bits': int(self.activation_bits)
        })
        return config

@tf.keras.utils.register_keras_serializable()
class QuantizedDense(tf.keras.layers.Layer):
    def __init__(self, units, activation=None, weight_bits=8, activation_bits=8, **kwargs):
        super(QuantizedDense, self).__init__(**kwargs)
        self.units = units
        self.activation_fn = tf.keras.activations.get(activation)
        self.weight_bits = weight_bits
        self.activation_bits = activation_bits
        
    def build(self, input_shape):
        input_dim = input_shape[-1]
        
        self.kernel = self.add_weight(
            name='kernel',
            shape=(input_dim, self.units),
            initializer='glorot_uniform',
            trainable=True
        )
        
        self.bias = self.add_weight(
            name='bias',
            shape=(self.units,),
            initializer='zeros',
            trainable=True
        )
        
        # Track min and max values for weights
        self.w_min = self.add_weight(
            name='w_min',
            shape=(1,),
            initializer=tf.constant_initializer(-1.0),
            trainable=False
        )
        
        self.w_max = self.add_weight(
            name='w_max',
            shape=(1,),
            initializer=tf.constant_initializer(1.0),
            trainable=False
        )
        
        # Track min and max values for activations
        self.a_min = self.add_weight(
            name='a_min',
            shape=(1,),
            initializer=tf.constant_initializer(0.0),
            trainable=False
        )
        
        self.a_max = self.add_weight(
            name='a_max',
            shape=(1,),
            initializer=tf.constant_initializer(6.0),
            trainable=False
        )
        
        self.built = True
    
    def call(self, inputs, training=None):
        if training:
            curr_w_min = tf.reduce_min(self.kernel)
            curr_w_max = tf.reduce_max(self.kernel)
            
            # Use EMA to update min/max values
            momentum = 0.9
            self.w_min.assign(momentum * self.w_min + (1 - momentum) * curr_w_min)
            self.w_max.assign(momentum * self.w_max + (1 - momentum) * curr_w_max)
        
        # Quantize weights
        quantized_kernel = fake_quantize(
            self.kernel,
            bits=self.weight_bits,
            min_value=self.w_min,
            max_value=self.w_max
        )
        
        # Standard dense operation with quantized weights
        outputs = tf.matmul(inputs, quantized_kernel)
        outputs = tf.nn.bias_add(outputs, self.bias)
        
        # Apply activation if specified
        if self.activation_fn is not None:
            outputs = self.activation_fn(outputs)
            
            # Update activation min/max during training
            if training:
                curr_a_min = tf.reduce_min(outputs)
                curr_a_max = tf.reduce_max(outputs)
                
                # Use EMA to update min/max values
                momentum = 0.9
                self.a_min.assign(momentum * self.a_min + (1 - momentum) * curr_a_min)
                self.a_max.assign(momentum * self.a_max + (1 - momentum) * curr_a_max)
            
            # Quantize activations
            outputs = fake_quantize(
                outputs,
                bits=self.activation_bits,
                min_value=self.a_min,
                max_value=self.a_max
            )
        
        return outputs
    
    def get_config(self):
        config = super(QuantizedDense, self).get_config()
        config.update({
            'units': self.units,
            'activation': tf.keras.activations.serialize(self.activation_fn),
            'weight_bits': self.weight_bits,
            'activation_bits': self.activation_bits
        })
        return config

# %%
# load the model with custom_objects
custom_objects = {
    'QuantizedConv2D': QuantizedConv2D,
    'QuantizedDense': QuantizedDense,
    'SimAM': SimAM
}

# %%
# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Dense, Dropout

# Step 2: Define CNN Model

def create_cnn_model(input_shape=(128, 128, 1), num_classes=NUM_CLASSES):
    """
    Creates the FN-Net model as described in the paper.
    
    Args:
        input_shape: Tuple of (height, width, channels). Default is (128, 128, 1) for grayscale
        num_classes: Number of output classes. Default is 2 for binary classification
        
    Returns:
        Keras Sequential model
    """
    model = Sequential([
        # First Convolutional Block
        Conv2D(16, (3, 3), padding='same', activation='relu', input_shape=input_shape),
        MaxPooling2D(pool_size=(6, 6), strides=6),
        
        # Second Convolutional Block
        Conv2D(32, (3, 3), padding='same', activation='relu'),
        MaxPooling2D(pool_size=(3, 3), strides=3),
        
        # Third Convolutional Block
        Conv2D(64, (3, 3), padding='same', activation='relu'),
        MaxPooling2D(pool_size=(2, 2), strides=2),
        
        # Fourth Convolutional Block
        Conv2D(96, (3, 3), padding='same', activation='relu'),
        MaxPooling2D(pool_size=(2, 2), strides=2),
        
        # Flatten layer
        Flatten(),
        # First Dense Layer with Dropout
        Dense(512, activation='relu'),
        Dropout(0.5),
        
        # Second Dense Layer
        Dense(256, activation='relu'),
        
        # Output Layer
        Dense(num_classes, activation='softmax')
    ])
    
    return model


# %%

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D,
    Dense, Dropout, Multiply, Activation, Flatten, Reshape, Permute
)
import tensorflow.keras.backend as K

def attention_block(x):
    """
    Applies a channel-wise attention mechanism to the input tensor.
    
    Args:
        x: Input tensor of shape (batch_size, h, w, c)
    
    Returns:
        Tensor after applying attention
    """
    # Global context vector (channel-wise average pooling)
    avg_pool = GlobalAveragePooling2D()(x)  # shape: (batch_size, channels)
    
    # Learn attention weights per channel
    attention = Dense(K.int_shape(x)[-1], activation='tanh')(avg_pool)  # shape: (batch_size, channels)
    attention = Activation('sigmoid')(attention)  # Optionally, use 'softmax' or 'tanh'
    
    # Reshape to multiply with input
    attention = Reshape((1, 1, K.int_shape(x)[-1]))(attention)  # shape: (batch_size, 1, 1, channels)
    
    # Apply attention weights to original feature maps
    return Multiply()([x, attention])

def create_cnn_model_with_attention(input_shape=(128, 128, 1), num_classes=2):
    inputs = Input(shape=input_shape)
    
    # Convolutional Blocks
    x = Conv2D(16, (3, 3), padding='same', activation='relu')(inputs)
    x = MaxPooling2D(pool_size=(6, 6), strides=6)(x)
    
    x = Conv2D(32, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(3, 3), strides=3)(x)
    
    x = Conv2D(64, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=2)(x)
    
    x = Conv2D(96, (3, 3), padding='same', activation='relu')(x)
    x = MaxPooling2D(pool_size=(2, 2), strides=2)(x)
    
    # Attention Block
    x = attention_block(x)
    
    # Fully Connected Layers
    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    
    outputs = Dense(num_classes, activation='softmax')(x)
    
    return Model(inputs, outputs)

# %% [markdown]
# **QUANTIZATION AWARE TRAINING (QAT)**

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Activation, Reshape, Multiply
from tensorflow.keras import backend as K

def quantized_attention_block(x):
    """
    Applies a channel-wise attention mechanism using QuantizedDense for QAT.
    
    Args:
        x: Input tensor of shape (batch_size, h, w, c)
    
    Returns:
        Tensor after applying attention
    """
    # Global context vector (channel-wise average pooling)
    avg_pool = GlobalAveragePooling2D()(x)  # shape: (batch_size, channels)

    # Learn attention weights per channel using QuantizedDense
    attention = QuantizedDense(K.int_shape(x)[-1], activation='tanh')(avg_pool)  # shape: (batch_size, channels)
    attention = Activation('sigmoid')(attention)  # Optionally, use 'softmax' or 'tanh'

    # Reshape to multiply with input
    attention = Reshape((1, 1, K.int_shape(x)[-1]))(attention)  # shape: (batch_size, 1, 1, channels)

    # Apply attention weights to original feature maps
    return Multiply()([x, attention])

# %%
def create_quantized_cnn_model(input_shape=(128, 128, 1), num_classes=10, weight_bits=8, activation_bits=8):
    """
    Creates a quantization-aware version of the model
    """
    inputs = tf.keras.Input(shape=input_shape)
    
    # First Convolutional Block
    x = QuantizedConv2D(16, (3, 3), padding='same', activation='relu', 
                        weight_bits=weight_bits, activation_bits=activation_bits)(inputs)
    x = tf.keras.layers.MaxPooling2D(pool_size=(6, 6), strides=6)(x)
    
    # Second Convolutional Block
    x = QuantizedConv2D(32, (3, 3), padding='same', activation='relu',
                        weight_bits=weight_bits, activation_bits=activation_bits)(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(3, 3), strides=3)(x)
    
    # Third Convolutional Block
    x = QuantizedConv2D(64, (3, 3), padding='same', activation='relu',
                        weight_bits=weight_bits, activation_bits=activation_bits)(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2)(x)
    
    # Fourth Convolutional Block
    x = QuantizedConv2D(96, (3, 3), padding='same', activation='relu',
                        weight_bits=weight_bits, activation_bits=activation_bits)(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2)(x)
    
    x = quantized_attention_block(x)
    # Flatten layer
    x = tf.keras.layers.Flatten()(x)
    
    # First Dense Layer with Dropout
    x = QuantizedDense(512, activation='relu',
                      weight_bits=weight_bits, activation_bits=activation_bits)(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    
    # Second Dense Layer
    x = QuantizedDense(256, activation='relu',
                      weight_bits=weight_bits, activation_bits=activation_bits)(x)
    
    # Output Layer 
    outputs = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# **OPTIMIZERS AND CALLBACK DEFINITIONS**

# %%
# Create the model
model = create_cnn_model_with_attention(INPUT_SHAPE, NUM_CLASSES)

# Compile the model
model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',  # Multi-class classification
    metrics=['accuracy']
)

# Display model summary
model.summary()
# Out:
# I0000 00:00:1754531809.158991     405 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1767 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        160 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 42, 42,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 42, 42,    │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 14, 14,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 14, 14,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 7, 7, 64)  │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 7, 7, 96)  │     55,392 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 3, 3, 96)  │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 96)        │          0 │ max_pooling2d_3[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 96)        │      9,312 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 96)        │          0 │ dense[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 96)  │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 3, 3, 96)  │          0 │ max_pooling2d_3[… │
# │                     │                   │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 864)       │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 512)       │    442,880 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │    131,328 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 5)         │      1,285 │ dense_2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 663,493 (2.53 MB)
#  Trainable params: 663,493 (2.53 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# %%
from tensorflow.keras.callbacks import Callback, EarlyStopping

class StopAtAccuracy(Callback):
    def __init__(self, target_acc=0.85):
        super(StopAtAccuracy, self).__init__()
        self.target_acc = target_acc

    def on_epoch_end(self, epoch, logs=None):
        if logs is None:
            return
        if logs.get("val_accuracy") >= self.target_acc:  # Stop when val_accuracy reaches target
            print(f"\nStopping training: Reached {self.target_acc * 100:.1f}% validation accuracy")
            self.model.stop_training = True


# %%

# %%
# Step 3: Callbacks
# Early stopping to prevent overfitting
early_stopping = EarlyStopping(
    monitor='val_loss', patience=7, restore_best_weights=True, verbose=1
)
stop_at_100 = StopAtAccuracy(target_acc=1)
# Learning rate scheduler to reduce LR when validation loss plateaus
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss', factor=0.1, patience=3, min_lr=1e-6, verbose=1
)

# %% [markdown]
# ***MODEL TRAINING***

# %%
# Initialize model (make sure create_model is defined)
model = create_cnn_model_with_attention(INPUT_SHAPE, NUM_CLASSES)

model.compile(optimizer='adam',
            loss='categorical_crossentropy',
            metrics=['accuracy'])

with tf.device('/GPU:0'):
    history = model.fit(
        train_generator,
        validation_data=test_generator,
        epochs=EPOCHS,
        callbacks=[early_stopping, lr_scheduler, ModelCheckpoint(f"/mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras", monitor='val_loss', save_best_only=True, verbose=1), stop_at_100],
        verbose=1
    )
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753951241.204143    5133 service.cc:148] XLA service 0x7f5ccc002100 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753951241.204645    5133 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2025-07-31 08:40:41.256398: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1753951241.511726    5133 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-07-31 08:40:43.849134: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1301', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-07-31 08:40:44.071862: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1301', 84 bytes spill stores, 84 bytes spill loads
#  1/91 ━━━━━━━━━━━━━━━━━━━━ 14:11 9s/step - accuracy: 0.0500 - loss: 1.6139
# I0000 00:00:1753951248.877489    5133 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.3764 - loss: 1.4171
# 2025-07-31 08:41:35.055440: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_157', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-07-31 08:41:51.895086: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_157', 12 bytes spill stores, 12 bytes spill loads
# Epoch 1: val_loss improved from inf to 1.05103, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 74s 717ms/step - accuracy: 0.3774 - loss: 1.4154 - val_accuracy: 0.5565 - val_loss: 1.0510 - learning_rate: 0.0010
# Epoch 2/100
# 90/91 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.5686 - loss: 1.0086
# Epoch 2: val_loss improved from 1.05103 to 0.91780, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 52s 577ms/step - accuracy: 0.5689 - loss: 1.0075 - val_accuracy: 0.5891 - val_loss: 0.9178 - learning_rate: 0.0010
# Epoch 3/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.6318 - loss: 0.8368
# Epoch 3: val_loss improved from 0.91780 to 0.73827, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 52s 575ms/step - accuracy: 0.6320 - loss: 0.8365 - val_accuracy: 0.6778 - val_loss: 0.7383 - learning_rate: 0.0010
# Epoch 4/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.7151 - loss: 0.7349
# Epoch 4: val_loss improved from 0.73827 to 0.68706, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 55s 600ms/step - accuracy: 0.7149 - loss: 0.7351 - val_accuracy: 0.6854 - val_loss: 0.6871 - learning_rate: 0.0010
# Epoch 5/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.6866 - loss: 0.7313
# Epoch 5: val_loss improved from 0.68706 to 0.64327, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 53s 581ms/step - accuracy: 0.6868 - loss: 0.7312 - val_accuracy: 0.7556 - val_loss: 0.6433 - learning_rate: 0.0010
# Epoch 6/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.7474 - loss: 0.6494
# Epoch 6: val_loss did not improve from 0.64327
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 54s 594ms/step - accuracy: 0.7473 - loss: 0.6497 - val_accuracy: 0.6996 - val_loss: 0.6888 - learning_rate: 0.0010
# Epoch 7/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.7405 - loss: 0.6423
# Epoch 7: val_loss improved from 0.64327 to 0.55648, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 50s 547ms/step - accuracy: 0.7407 - loss: 0.6418 - val_accuracy: 0.7732 - val_loss: 0.5565 - learning_rate: 0.0010
# Epoch 8/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.7750 - loss: 0.5748
# Epoch 8: val_loss did not improve from 0.55648
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 54s 592ms/step - accuracy: 0.7750 - loss: 0.5748 - val_accuracy: 0.7523 - val_loss: 0.5739 - learning_rate: 0.0010
# Epoch 9/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.7935 - loss: 0.5461
# Epoch 9: val_loss improved from 0.55648 to 0.52683, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 53s 586ms/step - accuracy: 0.7935 - loss: 0.5458 - val_accuracy: 0.7891 - val_loss: 0.5268 - learning_rate: 0.0010
# Epoch 10/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.7948 - loss: 0.5399
# Epoch 10: val_loss did not improve from 0.52683
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 52s 574ms/step - accuracy: 0.7948 - loss: 0.5400 - val_accuracy: 0.7816 - val_loss: 0.5789 - learning_rate: 0.0010
# Epoch 11/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.7925 - loss: 0.5207
# Epoch 11: val_loss did not improve from 0.52683
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 54s 587ms/step - accuracy: 0.7924 - loss: 0.5209 - val_accuracy: 0.7833 - val_loss: 0.5460 - learning_rate: 0.0010
# Epoch 12/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.8035 - loss: 0.4888
# Epoch 12: val_loss improved from 0.52683 to 0.51909, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 52s 572ms/step - accuracy: 0.8035 - loss: 0.4889 - val_accuracy: 0.7941 - val_loss: 0.5191 - learning_rate: 0.0010
# Epoch 13/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.8102 - loss: 0.4738
# Epoch 13: val_loss improved from 0.51909 to 0.48449, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 56s 613ms/step - accuracy: 0.8103 - loss: 0.4738 - val_accuracy: 0.8151 - val_loss: 0.4845 - learning_rate: 0.0010
# Epoch 14/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.8346 - loss: 0.4361
# Epoch 14: val_loss did not improve from 0.48449
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 53s 581ms/step - accuracy: 0.8344 - loss: 0.4364 - val_accuracy: 0.7749 - val_loss: 0.6152 - learning_rate: 0.0010
# Epoch 15/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.8139 - loss: 0.4904
# Epoch 15: val_loss did not improve from 0.48449
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 50s 544ms/step - accuracy: 0.8140 - loss: 0.4900 - val_accuracy: 0.7992 - val_loss: 0.4958 - learning_rate: 0.0010
# Epoch 16/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.8221 - loss: 0.4685
# Epoch 16: val_loss improved from 0.48449 to 0.47677, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 53s 577ms/step - accuracy: 0.8222 - loss: 0.4682 - val_accuracy: 0.8126 - val_loss: 0.4768 - learning_rate: 0.0010
# Epoch 17/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.8643 - loss: 0.3450
# Epoch 17: val_loss did not improve from 0.47677
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 52s 574ms/step - accuracy: 0.8641 - loss: 0.3454 - val_accuracy: 0.8285 - val_loss: 0.5153 - learning_rate: 0.0010
# Epoch 18/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.8460 - loss: 0.3930
# Epoch 18: val_loss improved from 0.47677 to 0.40072, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 54s 592ms/step - accuracy: 0.8461 - loss: 0.3927 - val_accuracy: 0.8577 - val_loss: 0.4007 - learning_rate: 0.0010
# Epoch 19/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.8737 - loss: 0.3368
# Epoch 19: val_loss did not improve from 0.40072
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 53s 579ms/step - accuracy: 0.8736 - loss: 0.3371 - val_accuracy: 0.8368 - val_loss: 0.4492 - learning_rate: 0.0010
# Epoch 20/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.8687 - loss: 0.3647
# Epoch 20: val_loss did not improve from 0.40072
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 53s 578ms/step - accuracy: 0.8686 - loss: 0.3647 - val_accuracy: 0.8577 - val_loss: 0.4182 - learning_rate: 0.0010
# Epoch 21/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.8746 - loss: 0.3398
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 21: val_loss did not improve from 0.40072
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 52s 569ms/step - accuracy: 0.8746 - loss: 0.3399 - val_accuracy: 0.8360 - val_loss: 0.4382 - learning_rate: 0.0010
# Epoch 22/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8910 - loss: 0.2845
# Epoch 22: val_loss improved from 0.40072 to 0.37519, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 52s 574ms/step - accuracy: 0.8911 - loss: 0.2843 - val_accuracy: 0.8812 - val_loss: 0.3752 - learning_rate: 1.0000e-04
# Epoch 23/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9069 - loss: 0.2446
# Epoch 23: val_loss improved from 0.37519 to 0.37194, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 50s 544ms/step - accuracy: 0.9069 - loss: 0.2446 - val_accuracy: 0.8795 - val_loss: 0.3719 - learning_rate: 1.0000e-04
# Epoch 24/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9159 - loss: 0.2316
# Epoch 24: val_loss improved from 0.37194 to 0.36953, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 50s 548ms/step - accuracy: 0.9159 - loss: 0.2316 - val_accuracy: 0.8837 - val_loss: 0.3695 - learning_rate: 1.0000e-04
# Epoch 25/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.9205 - loss: 0.2174
# Epoch 25: val_loss improved from 0.36953 to 0.35926, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 53s 577ms/step - accuracy: 0.9204 - loss: 0.2175 - val_accuracy: 0.8854 - val_loss: 0.3593 - learning_rate: 1.0000e-04
# Epoch 26/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.9184 - loss: 0.2209
# Epoch 26: val_loss did not improve from 0.35926
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 52s 574ms/step - accuracy: 0.9185 - loss: 0.2208 - val_accuracy: 0.8854 - val_loss: 0.3692 - learning_rate: 1.0000e-04
# Epoch 27/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.9254 - loss: 0.1987
# Epoch 27: val_loss improved from 0.35926 to 0.35685, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 53s 582ms/step - accuracy: 0.9253 - loss: 0.1989 - val_accuracy: 0.8921 - val_loss: 0.3569 - learning_rate: 1.0000e-04
# Epoch 28/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9205 - loss: 0.2002
# Epoch 28: val_loss improved from 0.35685 to 0.35452, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 52s 575ms/step - accuracy: 0.9205 - loss: 0.2003 - val_accuracy: 0.8912 - val_loss: 0.3545 - learning_rate: 1.0000e-04
# Epoch 29/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.9231 - loss: 0.2105
# Epoch 29: val_loss did not improve from 0.35452
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 53s 586ms/step - accuracy: 0.9231 - loss: 0.2104 - val_accuracy: 0.8745 - val_loss: 0.3971 - learning_rate: 1.0000e-04
# Epoch 30/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9247 - loss: 0.2003
# Epoch 30: val_loss did not improve from 0.35452
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 52s 568ms/step - accuracy: 0.9247 - loss: 0.2004 - val_accuracy: 0.8870 - val_loss: 0.3625 - learning_rate: 1.0000e-04
# Epoch 31/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.9292 - loss: 0.1942
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 31: val_loss did not improve from 0.35452
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 52s 569ms/step - accuracy: 0.9292 - loss: 0.1942 - val_accuracy: 0.8904 - val_loss: 0.3696 - learning_rate: 1.0000e-04
# Epoch 32/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.9287 - loss: 0.1935
# Epoch 32: val_loss did not improve from 0.35452
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 51s 565ms/step - accuracy: 0.9287 - loss: 0.1935 - val_accuracy: 0.8921 - val_loss: 0.3631 - learning_rate: 1.0000e-05
# Epoch 33/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.9296 - loss: 0.1859
# Epoch 33: val_loss did not improve from 0.35452
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 52s 572ms/step - accuracy: 0.9296 - loss: 0.1859 - val_accuracy: 0.8937 - val_loss: 0.3616 - learning_rate: 1.0000e-05
# Epoch 34/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.9286 - loss: 0.1897
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 34: val_loss did not improve from 0.35452
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 54s 588ms/step - accuracy: 0.9286 - loss: 0.1897 - val_accuracy: 0.8929 - val_loss: 0.3627 - learning_rate: 1.0000e-05
# Epoch 35/100
# 90/91 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.9288 - loss: 0.1804
# Epoch 35: val_loss did not improve from 0.35452
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 51s 562ms/step - accuracy: 0.9289 - loss: 0.1805 - val_accuracy: 0.8937 - val_loss: 0.3627 - learning_rate: 1.0000e-06
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 28.

# %%
modelh5 = tf.keras.models.load_model(f"/mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras", custom_objects=custom_objects)
print("model loaded")
# Convert to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_keras_model(modelh5)
print("converter set")
# Enable full integer quantization
converter.optimizations = [tf.lite.Optimize.DEFAULT]
print("optimizations initialized")
# Define a representative dataset function for calibration
def representative_dataset_gen():
    for i in range(100):  # Just use first 100 images for calibration
        img, _ = train_generator[i]
        for x in img:
            yield [np.expand_dims(x, axis=0).astype(np.float32)]


converter.representative_dataset = representative_dataset_gen
print("representative dataset initialized")
# Ensure all tensors are int8
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
print("type bit converstions done")
# Perform conversion
quantized_tflite_model = converter.convert()
print("quantized model obtained")
# Save the quantized model to disk
with open(f"/mnt/c/modelFiles/10splitsFlatten/tflite_NoQuant_Attention_SP_model.tflite", "wb") as f:
    f.write(quantized_tflite_model)
print("tfmodel saved")
# Out:
# model loaded
# converter set
# optimizations initialized
# representative dataset initialized
# type bit converstions done
# INFO:tensorflow:Assets written to: /tmp/tmpjqd2mmsj/assets
# INFO:tensorflow:Assets written to: /tmp/tmpjqd2mmsj/assets
# Saved artifact at '/tmp/tmpjqd2mmsj'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   140037614326928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037614327888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037614329616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037614328848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037613640912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037613641296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037613636112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037613643024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037613644752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037613645136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037613643984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037613640720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037613641872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037613645904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037613646096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140037613646672: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/srihari2895/TFProj/tfenv/lib/python3.12/site-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1753953159.897171     753 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1753953159.897245     753 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-07-31 09:12:39.897904: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpjqd2mmsj
# 2025-07-31 09:12:39.898617: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-07-31 09:12:39.898627: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpjqd2mmsj
# I0000 00:00:1753953159.906108     753 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# 2025-07-31 09:12:39.907149: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-07-31 09:12:39.950362: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpjqd2mmsj
# 2025-07-31 09:12:39.960604: I tensorflow/cc/saved_model/loader.cc:466] SavedModel load for tags { serve }; Status: success: OK. Took 62646 microseconds.
# quantized model obtained
# tfmodel saved
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8

# %%
from sklearn.model_selection import StratifiedKFold
from pathlib import Path
from datetime import datetime
import numpy as np
import tensorflow as tf
import os
import json

progress_file = "/mnt/c/modelFiles/10splitsFlatten/fold_progress.json"
if os.path.exists(progress_file):
    with open(progress_file, "r") as f:
        resume_from_fold = json.load(f).get("last_completed_fold", -1) + 1
else:
    resume_from_fold = 0

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
history_list = []

base_path = Path("/mnt/c/modelFiles/10splitsFlatten")
base_path.mkdir(parents=True, exist_ok=True)

model = create_quantized_cnn_model(INPUT_SHAPE, NUM_CLASSES)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
time1 = datetime.now()
for fold, (train_idx, val_idx) in enumerate(skf.split(all_filepaths, all_labels)):
    if fold < resume_from_fold:
        print(f"[INFO] Skipping Fold {fold}, already completed.")
        continue

    print(f"\n[INFO] Fold {fold}")
    # Split data
    X_train, y_train = all_filepaths[train_idx], all_labels[train_idx]
    X_val, y_val = all_filepaths[val_idx], all_labels[val_idx]

    # Generators
    train_generator = CustomDataGenerator(X_train, y_train, BATCH_SIZE, IMG_SIZE, NUM_CLASSES, shuffle=True, class_indices=class_indices)
    val_generator = CustomDataGenerator(X_val, y_val, BATCH_SIZE, IMG_SIZE, NUM_CLASSES, shuffle=False, class_indices=class_indices)

    # Define model paths
    keras_path = base_path / f"greyColor_Attention_kfold_model.keras"

    # Train model
    with tf.device('/GPU:0'):
        history = model.fit(
            train_generator,
            validation_data=val_generator,
            epochs=EPOCHS,
            callbacks=[early_stopping, lr_scheduler, ModelCheckpoint(str(keras_path), monitor='val_loss', save_best_only=True, verbose=1), stop_at_100],
            verbose=1
        )

    if fold == 0:
        model.summary()

    # Save model
    print(f"[INFO] Saved model for Fold {fold} to {keras_path.name}")
    with open(f"/mnt/c/modelFiles/10splitsFlatten/history_fold_{fold}.json", "w") as f:
        json.dump(history.history, f)
    history_list.append(history)
    with open(progress_file, "w") as f:
        json.dump({"last_completed_fold": fold}, f)
time2 = datetime.now()
difference = time2 - time1
minutes = divmod(difference.total_seconds(), 60) 
print('Difference in minutes: ', minutes[0],
      'minutes', minutes[1], 'seconds')
# Out:
# [INFO] Fold 0
# /home/srihari2895/TFProj/tfenv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.92572, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 50s 424ms/step - accuracy: 0.3857 - loss: 1.3755 - val_accuracy: 0.5813 - val_loss: 0.9257 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.92572 to 0.76913, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 49s 448ms/step - accuracy: 0.5981 - loss: 0.9423 - val_accuracy: 0.6833 - val_loss: 0.7691 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.76913
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 47s 429ms/step - accuracy: 0.6618 - loss: 0.7814 - val_accuracy: 0.6458 - val_loss: 0.7728 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.76913 to 0.68360, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 45s 418ms/step - accuracy: 0.6745 - loss: 0.7449 - val_accuracy: 0.7104 - val_loss: 0.6836 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.68360 to 0.64761, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 46s 425ms/step - accuracy: 0.7431 - loss: 0.6376 - val_accuracy: 0.7250 - val_loss: 0.6476 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.64761 to 0.55086, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 48s 439ms/step - accuracy: 0.7377 - loss: 0.6447 - val_accuracy: 0.7646 - val_loss: 0.5509 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.55086 to 0.53353, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 45s 412ms/step - accuracy: 0.7721 - loss: 0.5651 - val_accuracy: 0.7688 - val_loss: 0.5335 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.53353 to 0.48452, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 44s 410ms/step - accuracy: 0.7957 - loss: 0.5221 - val_accuracy: 0.8042 - val_loss: 0.4845 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.48452 to 0.47282, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 43s 401ms/step - accuracy: 0.7912 - loss: 0.5113 - val_accuracy: 0.8125 - val_loss: 0.4728 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.47282 to 0.46096, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 42s 390ms/step - accuracy: 0.8001 - loss: 0.4883 - val_accuracy: 0.8229 - val_loss: 0.4610 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.46096 to 0.42723, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 45s 416ms/step - accuracy: 0.8029 - loss: 0.4763 - val_accuracy: 0.8250 - val_loss: 0.4272 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.42723
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 47s 431ms/step - accuracy: 0.8160 - loss: 0.4576 - val_accuracy: 0.8125 - val_loss: 0.4482 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.42723
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 43s 395ms/step - accuracy: 0.8390 - loss: 0.4079 - val_accuracy: 0.7937 - val_loss: 0.4820 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 14: val_loss did not improve from 0.42723
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 46s 422ms/step - accuracy: 0.8317 - loss: 0.4201 - val_accuracy: 0.7958 - val_loss: 0.4840 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.42723 to 0.33496, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 46s 418ms/step - accuracy: 0.8763 - loss: 0.3290 - val_accuracy: 0.8542 - val_loss: 0.3350 - learning_rate: 1.0000e-04
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.33496
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 46s 426ms/step - accuracy: 0.8879 - loss: 0.3048 - val_accuracy: 0.8562 - val_loss: 0.3366 - learning_rate: 1.0000e-04
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.33496 to 0.32232, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 45s 412ms/step - accuracy: 0.8944 - loss: 0.2765 - val_accuracy: 0.8646 - val_loss: 0.3223 - learning_rate: 1.0000e-04
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.32232 to 0.32162, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 43s 397ms/step - accuracy: 0.8940 - loss: 0.2632 - val_accuracy: 0.8562 - val_loss: 0.3216 - learning_rate: 1.0000e-04
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.32162 to 0.30444, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 46s 422ms/step - accuracy: 0.8989 - loss: 0.2591 - val_accuracy: 0.8521 - val_loss: 0.3044 - learning_rate: 1.0000e-04
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.30444
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 43s 395ms/step - accuracy: 0.8940 - loss: 0.2717 - val_accuracy: 0.8562 - val_loss: 0.3113 - learning_rate: 1.0000e-04
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.30444 to 0.29823, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 43s 395ms/step - accuracy: 0.9018 - loss: 0.2642 - val_accuracy: 0.8687 - val_loss: 0.2982 - learning_rate: 1.0000e-04
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.29823
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 41s 374ms/step - accuracy: 0.9042 - loss: 0.2511 - val_accuracy: 0.8750 - val_loss: 0.3080 - learning_rate: 1.0000e-04
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.29823
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 42s 387ms/step - accuracy: 0.9049 - loss: 0.2463 - val_accuracy: 0.8604 - val_loss: 0.3073 - learning_rate: 1.0000e-04
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.29823 to 0.29538, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 41s 375ms/step - accuracy: 0.9041 - loss: 0.2338 - val_accuracy: 0.8813 - val_loss: 0.2954 - learning_rate: 1.0000e-04
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.29538
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 41s 377ms/step - accuracy: 0.9102 - loss: 0.2324 - val_accuracy: 0.8646 - val_loss: 0.3025 - learning_rate: 1.0000e-04
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.29538
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 43s 393ms/step - accuracy: 0.9116 - loss: 0.2330 - val_accuracy: 0.8583 - val_loss: 0.2981 - learning_rate: 1.0000e-04
# Epoch 27/100
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 27: val_loss did not improve from 0.29538
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 41s 374ms/step - accuracy: 0.9055 - loss: 0.2277 - val_accuracy: 0.8729 - val_loss: 0.3041 - learning_rate: 1.0000e-04
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.29538
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 43s 398ms/step - accuracy: 0.9129 - loss: 0.2271 - val_accuracy: 0.8583 - val_loss: 0.3024 - learning_rate: 1.0000e-05
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.29538
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 42s 382ms/step - accuracy: 0.9081 - loss: 0.2301 - val_accuracy: 0.8667 - val_loss: 0.2986 - learning_rate: 1.0000e-05
# Epoch 30/100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 30: val_loss did not improve from 0.29538
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 43s 394ms/step - accuracy: 0.9059 - loss: 0.2321 - val_accuracy: 0.8667 - val_loss: 0.3031 - learning_rate: 1.0000e-05
# Epoch 31/100
#
# Epoch 31: val_loss improved from 0.29538 to 0.29511, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 42s 392ms/step - accuracy: 0.9009 - loss: 0.2394 - val_accuracy: 0.8750 - val_loss: 0.2951 - learning_rate: 1.0000e-06
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.29511
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 42s 383ms/step - accuracy: 0.9083 - loss: 0.2258 - val_accuracy: 0.8708 - val_loss: 0.2985 - learning_rate: 1.0000e-06
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.29511
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 42s 386ms/step - accuracy: 0.9143 - loss: 0.2281 - val_accuracy: 0.8729 - val_loss: 0.2995 - learning_rate: 1.0000e-06
# Epoch 34/100
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 34: val_loss did not improve from 0.29511
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 42s 390ms/step - accuracy: 0.9091 - loss: 0.2208 - val_accuracy: 0.8813 - val_loss: 0.2954 - learning_rate: 1.0000e-06
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.29511
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 43s 392ms/step - accuracy: 0.9146 - loss: 0.2249 - val_accuracy: 0.8792 - val_loss: 0.2964 - learning_rate: 1.0000e-06
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.29511
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 42s 385ms/step - accuracy: 0.9140 - loss: 0.2203 - val_accuracy: 0.8667 - val_loss: 0.2983 - learning_rate: 1.0000e-06
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.29511
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 40s 371ms/step - accuracy: 0.9016 - loss: 0.2390 - val_accuracy: 0.8729 - val_loss: 0.2972 - learning_rate: 1.0000e-06
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.29511
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 44s 404ms/step - accuracy: 0.9063 - loss: 0.2374 - val_accuracy: 0.8771 - val_loss: 0.2977 - learning_rate: 1.0000e-06
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 31.
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ quantized_conv2d_8  │ (None, 256, 256,  │        164 │ input_layer_3[0]… │
# │ (QuantizedConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_12    │ (None, 42, 42,    │          0 │ quantized_conv2d… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ quantized_conv2d_9  │ (None, 42, 42,    │      4,644 │ max_pooling2d_12… │
# │ (QuantizedConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_13    │ (None, 14, 14,    │          0 │ quantized_conv2d… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ quantized_conv2d_10 │ (None, 14, 14,    │     18,500 │ max_pooling2d_13… │
# │ (QuantizedConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_14    │ (None, 7, 7, 64)  │          0 │ quantized_conv2d… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ quantized_conv2d_11 │ (None, 7, 7, 96)  │     55,396 │ max_pooling2d_14… │
# │ (QuantizedConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_15    │ (None, 3, 3, 96)  │          0 │ quantized_conv2d… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 96)        │          0 │ max_pooling2d_15… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ quantized_dense_6   │ (None, 96)        │      9,316 │ global_average_p… │
# │ (QuantizedDense)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 96)        │          0 │ quantized_dense_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 1, 1, 96)  │          0 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 3, 3, 96)  │          0 │ max_pooling2d_15… │
# │ (Multiply)          │                   │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 864)       │          0 │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ quantized_dense_7   │ (None, 512)       │    442,884 │ flatten_3[0][0]   │
# │ (QuantizedDense)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 512)       │          0 │ quantized_dense_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ quantized_dense_8   │ (None, 256)       │    131,332 │ dropout_3[0][0]   │
# │ (QuantizedDense)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 5)         │      1,285 │ quantized_dense_… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,990,509 (7.59 MB)
#  Trainable params: 663,493 (2.53 MB)
#  Non-trainable params: 28 (112.00 B)
#  Optimizer params: 1,326,988 (5.06 MB)
# [INFO] Saved model for Fold 0 to greyColor_Attention_kfold_model.keras
#
# [INFO] Fold 1
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.22149, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_Attention_kfold_model.keras
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 41s 374ms/step - accuracy: 0.9064 - loss: 0.2319 - val_accuracy: 0.8958 - val_loss: 0.2215 - learning_rate: 1.0000e-06
# Epoch 2/100
#  36/108 ━━━━━━━━━━━━━━━━━━━━ 24s 339ms/step - accuracy: 0.9226 - loss: 0.2126

# %%
# Convert to TFLite Quantized model
tflite_path = base_path / f"Attention_kfold_model.tflite"

def representative_dataset_gen():
    for i in range(100):  # Use first 100 batches
        img_batch, _ = train_generator[i]
        for img in img_batch:
            yield [np.expand_dims(img.astype(np.float32), axis=0)]

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_model = converter.convert()
tflite_path.write_bytes(tflite_model)

# %%
from sklearn.model_selection import StratifiedKFold
from pathlib import Path
import numpy as np
import tensorflow as tf
import os
import json
from datetime import datetime

progress_file = "/mnt/c/modelFiles/10splitsFlatten/fold_progress.json"
if os.path.exists(progress_file):
    with open(progress_file, "r") as f:
        resume_from_fold = json.load(f).get("last_completed_fold", -1) + 1
else:
    resume_from_fold = 0

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
history_list = []

base_path = Path("/mnt/c/modelFiles/10splitsFlatten")
base_path.mkdir(parents=True, exist_ok=True)
time1 = datetime.now()
print(time1)
for fold, (train_idx, val_idx) in enumerate(skf.split(X_train_main, y_train_main)):
    if fold < resume_from_fold:
        print(f"[INFO] Skipping Fold {fold}, already completed.")
        continue

    print(f"\n[INFO] Fold {fold}")
    # Split data
    X_train, y_train = X_train_main[train_idx], y_train_main[train_idx]
    X_val, y_val = X_train_main[val_idx], y_train_main[val_idx]

    # Generators
    train_generator = CustomDataGenerator(X_train, y_train, BATCH_SIZE, IMG_SIZE, NUM_CLASSES, shuffle=True, class_indices=class_indices)
    val_generator = CustomDataGenerator(X_val, y_val, BATCH_SIZE, IMG_SIZE, NUM_CLASSES, shuffle=False, class_indices=class_indices)

    # Create and compile model
    model = create_cnn_model_with_attention(INPUT_SHAPE, NUM_CLASSES)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Define model paths
    keras_path = base_path / f"greyColor_NoQuant_Attention_kfold_model_{fold}.keras"
    tflite_path = base_path / f"NoQuant_Attention_kfold_model_{fold}.tflite"

    # Train model
    with tf.device('/GPU:0'):
        history = model.fit(
            train_generator,
            validation_data=val_generator,
            epochs=EPOCHS,
            callbacks=[early_stopping, lr_scheduler, ModelCheckpoint(str(keras_path), monitor='val_loss', save_best_only=True, verbose=1), stop_at_100],
            verbose=1
        )

    if fold == 0:
        model.summary()

    # Save model
    print(f"[INFO] Saved model for Fold {fold} to {keras_path.name}")
    with open(f"/mnt/c/modelFiles/10splitsFlatten/history_fold_{fold}.json", "w") as f:
        json.dump(history.history, f)
    history_list.append(history)

    # Convert to TFLite Quantized model
    def representative_dataset_gen():
        for i in range(100):  # Use first 100 batches
            img_batch, _ = train_generator[i]
            for img in img_batch:
                yield [np.expand_dims(img.astype(np.float32), axis=0)]

    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    converter.representative_dataset = representative_dataset_gen
    converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
    converter.inference_input_type = tf.int8
    converter.inference_output_type = tf.int8

    tflite_model = converter.convert()
    tflite_path.write_bytes(tflite_model)
    print(f"[INFO] Saved quantized TFLite model for Fold {fold} to {tflite_path.name}")
    with open(progress_file, "w") as f:
        json.dump({"last_completed_fold": fold}, f)
time2 = datetime.now()
print(time2)
difference = time2 - time1
minutes = divmod(difference.total_seconds(), 60) 
print('Difference in minutes: ', minutes[0],'minutes', minutes[1], 'seconds')
# Out:
# 2025-08-07 09:44:53.928247
#
# [INFO] Fold 0
# I0000 00:00:1754559895.023921     406 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1767 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# /home/srihari2895/TFProj/tfenv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754559898.437195     765 service.cc:148] XLA service 0x7f14940156d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754559898.437473     765 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2025-08-07 09:44:58.485794: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1754559898.706316     765 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-08-07 09:45:00.851964: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1301', 48 bytes spill stores, 48 bytes spill loads
#
# 2025-08-07 09:45:01.038382: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1301', 84 bytes spill stores, 84 bytes spill loads
#   1/103 ━━━━━━━━━━━━━━━━━━━━ 14:28 9s/step - accuracy: 0.2250 - loss: 1.6103
# I0000 00:00:1754559905.278562     765 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.4107 - loss: 1.3778
# 2025-08-07 09:45:54.627287: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_157', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-08-07 09:46:01.546538: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_164', 4 bytes spill stores, 4 bytes spill loads
# Epoch 1: val_loss improved from inf to 0.93730, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 66s 564ms/step - accuracy: 0.4115 - loss: 1.3762 - val_accuracy: 0.6031 - val_loss: 0.9373 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.93730 to 0.82628, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 45s 437ms/step - accuracy: 0.5796 - loss: 0.9594 - val_accuracy: 0.6075 - val_loss: 0.8263 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.82628 to 0.70813, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 43s 418ms/step - accuracy: 0.6437 - loss: 0.8423 - val_accuracy: 0.7018 - val_loss: 0.7081 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.70813
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 380ms/step - accuracy: 0.6992 - loss: 0.7051 - val_accuracy: 0.7237 - val_loss: 0.7120 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.70813 to 0.56082, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 398ms/step - accuracy: 0.7352 - loss: 0.6563 - val_accuracy: 0.7829 - val_loss: 0.5608 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.56082 to 0.54151, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 386ms/step - accuracy: 0.7641 - loss: 0.5746 - val_accuracy: 0.7873 - val_loss: 0.5415 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.54151 to 0.52893, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 387ms/step - accuracy: 0.7762 - loss: 0.5403 - val_accuracy: 0.7982 - val_loss: 0.5289 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.52893 to 0.50825, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 381ms/step - accuracy: 0.8057 - loss: 0.4919 - val_accuracy: 0.7939 - val_loss: 0.5083 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.50825 to 0.49617, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 391ms/step - accuracy: 0.7979 - loss: 0.5060 - val_accuracy: 0.8092 - val_loss: 0.4962 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.49617 to 0.46189, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 397ms/step - accuracy: 0.8209 - loss: 0.4383 - val_accuracy: 0.8026 - val_loss: 0.4619 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.46189 to 0.45919, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 398ms/step - accuracy: 0.8209 - loss: 0.4538 - val_accuracy: 0.8158 - val_loss: 0.4592 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.45919 to 0.39982, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 398ms/step - accuracy: 0.8517 - loss: 0.3669 - val_accuracy: 0.8377 - val_loss: 0.3998 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.39982 to 0.36046, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 399ms/step - accuracy: 0.8642 - loss: 0.3472 - val_accuracy: 0.8465 - val_loss: 0.3605 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.36046
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 391ms/step - accuracy: 0.8667 - loss: 0.3324 - val_accuracy: 0.8706 - val_loss: 0.3686 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.36046
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 395ms/step - accuracy: 0.8514 - loss: 0.3692 - val_accuracy: 0.8509 - val_loss: 0.4007 - learning_rate: 0.0010
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.36046 to 0.35725, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 378ms/step - accuracy: 0.8628 - loss: 0.3457 - val_accuracy: 0.8596 - val_loss: 0.3573 - learning_rate: 0.0010
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.35725 to 0.31662, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 393ms/step - accuracy: 0.8875 - loss: 0.3026 - val_accuracy: 0.8969 - val_loss: 0.3166 - learning_rate: 0.0010
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.31662 to 0.29130, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 406ms/step - accuracy: 0.9011 - loss: 0.2616 - val_accuracy: 0.8904 - val_loss: 0.2913 - learning_rate: 0.0010
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.29130
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 390ms/step - accuracy: 0.9098 - loss: 0.2440 - val_accuracy: 0.8838 - val_loss: 0.3227 - learning_rate: 0.0010
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.29130 to 0.28609, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 392ms/step - accuracy: 0.9150 - loss: 0.2349 - val_accuracy: 0.8925 - val_loss: 0.2861 - learning_rate: 0.0010
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.28609
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 385ms/step - accuracy: 0.9160 - loss: 0.2138 - val_accuracy: 0.8575 - val_loss: 0.4284 - learning_rate: 0.0010
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.28609
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 390ms/step - accuracy: 0.9138 - loss: 0.2319 - val_accuracy: 0.8838 - val_loss: 0.3019 - learning_rate: 0.0010
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.28609 to 0.28279, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 365ms/step - accuracy: 0.9299 - loss: 0.1889 - val_accuracy: 0.9123 - val_loss: 0.2828 - learning_rate: 0.0010
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.28279 to 0.28142, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 380ms/step - accuracy: 0.9342 - loss: 0.1849 - val_accuracy: 0.8882 - val_loss: 0.2814 - learning_rate: 0.0010
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.28142
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 392ms/step - accuracy: 0.9325 - loss: 0.1799 - val_accuracy: 0.8969 - val_loss: 0.2825 - learning_rate: 0.0010
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.28142
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 386ms/step - accuracy: 0.9296 - loss: 0.1855 - val_accuracy: 0.8860 - val_loss: 0.3447 - learning_rate: 0.0010
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.28142 to 0.27604, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 397ms/step - accuracy: 0.9425 - loss: 0.1539 - val_accuracy: 0.9101 - val_loss: 0.2760 - learning_rate: 0.0010
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.27604
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 404ms/step - accuracy: 0.9463 - loss: 0.1550 - val_accuracy: 0.9079 - val_loss: 0.3188 - learning_rate: 0.0010
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.27604
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 380ms/step - accuracy: 0.9466 - loss: 0.1584 - val_accuracy: 0.9057 - val_loss: 0.2870 - learning_rate: 0.0010
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.27604 to 0.27234, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_0.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 376ms/step - accuracy: 0.9445 - loss: 0.1521 - val_accuracy: 0.9123 - val_loss: 0.2723 - learning_rate: 0.0010
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.27234
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 378ms/step - accuracy: 0.9533 - loss: 0.1237 - val_accuracy: 0.9079 - val_loss: 0.2916 - learning_rate: 0.0010
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.27234
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 404ms/step - accuracy: 0.9484 - loss: 0.1388 - val_accuracy: 0.8991 - val_loss: 0.3461 - learning_rate: 0.0010
# Epoch 33/100
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 33: val_loss did not improve from 0.27234
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 407ms/step - accuracy: 0.9556 - loss: 0.1180 - val_accuracy: 0.9167 - val_loss: 0.3120 - learning_rate: 0.0010
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.27234
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 394ms/step - accuracy: 0.9734 - loss: 0.0762 - val_accuracy: 0.9167 - val_loss: 0.2809 - learning_rate: 1.0000e-04
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.27234
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 400ms/step - accuracy: 0.9751 - loss: 0.0821 - val_accuracy: 0.9123 - val_loss: 0.2937 - learning_rate: 1.0000e-04
# Epoch 36/100
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 36: val_loss did not improve from 0.27234
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 380ms/step - accuracy: 0.9778 - loss: 0.0706 - val_accuracy: 0.9123 - val_loss: 0.2895 - learning_rate: 1.0000e-04
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.27234
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 378ms/step - accuracy: 0.9796 - loss: 0.0618 - val_accuracy: 0.9123 - val_loss: 0.2941 - learning_rate: 1.0000e-05
# Epoch 37: early stopping
# Restoring model weights from the end of the best epoch: 30.
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        160 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 42, 42,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 42, 42,    │      4,640 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 14, 14,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 14, 14,    │     18,496 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 7, 7, 64)  │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 7, 7, 96)  │     55,392 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 3, 3, 96)  │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 96)        │          0 │ max_pooling2d_3[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 96)        │      9,312 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 96)        │          0 │ dense[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 96)  │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 3, 3, 96)  │          0 │ max_pooling2d_3[… │
# │                     │                   │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 864)       │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 512)       │    442,880 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │    131,328 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 5)         │      1,285 │ dense_2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,990,481 (7.59 MB)
#  Trainable params: 663,493 (2.53 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,326,988 (5.06 MB)
# [INFO] Saved model for Fold 0 to greyColor_NoQuant_Attention_kfold_model_0.keras
# INFO:tensorflow:Assets written to: /tmp/tmps93sln3q/assets
# INFO:tensorflow:Assets written to: /tmp/tmps93sln3q/assets
# Saved artifact at '/tmp/tmps93sln3q'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   139730303489936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303491088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303492624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303491472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303490320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303493968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303491856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303493392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303494928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303496080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303496272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303496848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303495504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303498000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303498192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139730303498768: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/srihari2895/TFProj/tfenv/lib/python3.12/site-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1754561425.448232     406 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1754561425.448270     406 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-08-07 10:10:25.448555: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmps93sln3q
# 2025-08-07 10:10:25.449067: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-08-07 10:10:25.449077: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmps93sln3q
# I0000 00:00:1754561425.457755     406 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# 2025-08-07 10:10:25.458767: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-08-07 10:10:25.498070: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmps93sln3q
# 2025-08-07 10:10:25.508231: I tensorflow/cc/saved_model/loader.cc:466] SavedModel load for tags { serve }; Status: success: OK. Took 59677 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# /home/srihari2895/TFProj/tfenv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# [INFO] Saved quantized TFLite model for Fold 0 to NoQuant_Attention_kfold_model_0.tflite
#
# [INFO] Fold 1
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.97662, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 44s 400ms/step - accuracy: 0.4143 - loss: 1.3665 - val_accuracy: 0.6294 - val_loss: 0.9766 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.97662 to 0.78499, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 380ms/step - accuracy: 0.5940 - loss: 0.9564 - val_accuracy: 0.6798 - val_loss: 0.7850 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.78499 to 0.76560, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 385ms/step - accuracy: 0.6555 - loss: 0.8181 - val_accuracy: 0.6754 - val_loss: 0.7656 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.76560 to 0.70629, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 373ms/step - accuracy: 0.6767 - loss: 0.7443 - val_accuracy: 0.6776 - val_loss: 0.7063 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.70629 to 0.69777, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 384ms/step - accuracy: 0.7335 - loss: 0.6558 - val_accuracy: 0.6886 - val_loss: 0.6978 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.69777 to 0.55379, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 381ms/step - accuracy: 0.7317 - loss: 0.6714 - val_accuracy: 0.7632 - val_loss: 0.5538 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.55379 to 0.50781, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 402ms/step - accuracy: 0.7843 - loss: 0.5638 - val_accuracy: 0.8026 - val_loss: 0.5078 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.50781 to 0.49261, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 367ms/step - accuracy: 0.8080 - loss: 0.5218 - val_accuracy: 0.8268 - val_loss: 0.4926 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.49261 to 0.47861, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 375ms/step - accuracy: 0.8184 - loss: 0.4796 - val_accuracy: 0.8246 - val_loss: 0.4786 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.47861 to 0.43260, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 387ms/step - accuracy: 0.8299 - loss: 0.4468 - val_accuracy: 0.8246 - val_loss: 0.4326 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.43260
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 386ms/step - accuracy: 0.8568 - loss: 0.3733 - val_accuracy: 0.8333 - val_loss: 0.4361 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.43260 to 0.40997, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 387ms/step - accuracy: 0.8756 - loss: 0.3514 - val_accuracy: 0.8750 - val_loss: 0.4100 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.40997 to 0.33150, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 381ms/step - accuracy: 0.8796 - loss: 0.3473 - val_accuracy: 0.8728 - val_loss: 0.3315 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.33150 to 0.28170, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 380ms/step - accuracy: 0.9012 - loss: 0.2937 - val_accuracy: 0.8794 - val_loss: 0.2817 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.28170
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 367ms/step - accuracy: 0.9024 - loss: 0.2682 - val_accuracy: 0.8575 - val_loss: 0.3488 - learning_rate: 0.0010
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.28170
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 370ms/step - accuracy: 0.9240 - loss: 0.2240 - val_accuracy: 0.8618 - val_loss: 0.3497 - learning_rate: 0.0010
# Epoch 17/100
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 17: val_loss did not improve from 0.28170
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 390ms/step - accuracy: 0.9003 - loss: 0.2639 - val_accuracy: 0.8772 - val_loss: 0.3227 - learning_rate: 0.0010
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.28170 to 0.25441, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 388ms/step - accuracy: 0.9212 - loss: 0.2141 - val_accuracy: 0.8991 - val_loss: 0.2544 - learning_rate: 1.0000e-04
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.25441 to 0.25024, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 385ms/step - accuracy: 0.9315 - loss: 0.1939 - val_accuracy: 0.9013 - val_loss: 0.2502 - learning_rate: 1.0000e-04
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.25024
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 374ms/step - accuracy: 0.9449 - loss: 0.1685 - val_accuracy: 0.8991 - val_loss: 0.2593 - learning_rate: 1.0000e-04
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.25024 to 0.24738, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 372ms/step - accuracy: 0.9426 - loss: 0.1637 - val_accuracy: 0.8991 - val_loss: 0.2474 - learning_rate: 1.0000e-04
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.24738
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 370ms/step - accuracy: 0.9449 - loss: 0.1584 - val_accuracy: 0.8991 - val_loss: 0.2534 - learning_rate: 1.0000e-04
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.24738 to 0.23615, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_1.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 373ms/step - accuracy: 0.9430 - loss: 0.1492 - val_accuracy: 0.9123 - val_loss: 0.2361 - learning_rate: 1.0000e-04
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.23615
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 386ms/step - accuracy: 0.9481 - loss: 0.1452 - val_accuracy: 0.9035 - val_loss: 0.2481 - learning_rate: 1.0000e-04
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.23615
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 386ms/step - accuracy: 0.9576 - loss: 0.1326 - val_accuracy: 0.9057 - val_loss: 0.2450 - learning_rate: 1.0000e-04
# Epoch 26/100
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 26: val_loss did not improve from 0.23615
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 398ms/step - accuracy: 0.9565 - loss: 0.1295 - val_accuracy: 0.8991 - val_loss: 0.2550 - learning_rate: 1.0000e-04
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.23615
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 12009s 118s/step - accuracy: 0.9493 - loss: 0.1443 - val_accuracy: 0.9057 - val_loss: 0.2432 - learning_rate: 1.0000e-05
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.23615
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 45s 433ms/step - accuracy: 0.9474 - loss: 0.1430 - val_accuracy: 0.9057 - val_loss: 0.2420 - learning_rate: 1.0000e-05
# Epoch 29/100
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 29: val_loss did not improve from 0.23615
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 44s 421ms/step - accuracy: 0.9515 - loss: 0.1421 - val_accuracy: 0.9057 - val_loss: 0.2428 - learning_rate: 1.0000e-05
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.23615
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 43s 420ms/step - accuracy: 0.9474 - loss: 0.1473 - val_accuracy: 0.9057 - val_loss: 0.2425 - learning_rate: 1.0000e-06
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 23.
# [INFO] Saved model for Fold 1 to greyColor_NoQuant_Attention_kfold_model_1.keras
# INFO:tensorflow:Assets written to: /tmp/tmpc6f0bi6r/assets
# INFO:tensorflow:Assets written to: /tmp/tmpc6f0bi6r/assets
# Saved artifact at '/tmp/tmpc6f0bi6r'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name='keras_tensor_19')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   139729841618576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139729841616656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139729841618384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139729841615888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139729841615696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139729841615120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139729841614928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139729841614352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139729841614160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139729841613584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139729841613392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139729841612816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139729841613008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139729841613200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139728373777232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139728373778000: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/srihari2895/TFProj/tfenv/lib/python3.12/site-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1754574678.811212     406 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1754574678.811247     406 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-08-07 13:51:18.811365: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpc6f0bi6r
# 2025-08-07 13:51:18.811971: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-08-07 13:51:18.811980: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpc6f0bi6r
# 2025-08-07 13:51:18.817648: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-08-07 13:51:18.854264: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpc6f0bi6r
# 2025-08-07 13:51:18.864000: I tensorflow/cc/saved_model/loader.cc:466] SavedModel load for tags { serve }; Status: success: OK. Took 52637 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# /home/srihari2895/TFProj/tfenv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# [INFO] Saved quantized TFLite model for Fold 1 to NoQuant_Attention_kfold_model_1.tflite
#
# [INFO] Fold 2
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.91278, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 50s 452ms/step - accuracy: 0.4201 - loss: 1.3791 - val_accuracy: 0.5965 - val_loss: 0.9128 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.91278 to 0.80487, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 399ms/step - accuracy: 0.6139 - loss: 0.8954 - val_accuracy: 0.6404 - val_loss: 0.8049 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.80487 to 0.62138, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 48s 465ms/step - accuracy: 0.6748 - loss: 0.7713 - val_accuracy: 0.7588 - val_loss: 0.6214 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.62138 to 0.60365, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 408ms/step - accuracy: 0.7248 - loss: 0.6797 - val_accuracy: 0.7697 - val_loss: 0.6037 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.60365 to 0.59321, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 405ms/step - accuracy: 0.7456 - loss: 0.6153 - val_accuracy: 0.7588 - val_loss: 0.5932 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.59321 to 0.54157, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 401ms/step - accuracy: 0.7659 - loss: 0.5840 - val_accuracy: 0.7741 - val_loss: 0.5416 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.54157 to 0.48687, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 45s 429ms/step - accuracy: 0.7829 - loss: 0.5592 - val_accuracy: 0.8158 - val_loss: 0.4869 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.48687
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 374ms/step - accuracy: 0.7985 - loss: 0.5129 - val_accuracy: 0.7390 - val_loss: 0.6412 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.48687 to 0.47524, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 380ms/step - accuracy: 0.7959 - loss: 0.5120 - val_accuracy: 0.8246 - val_loss: 0.4752 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.47524
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 373ms/step - accuracy: 0.8040 - loss: 0.5121 - val_accuracy: 0.7544 - val_loss: 0.6240 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.47524 to 0.43254, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 367ms/step - accuracy: 0.8236 - loss: 0.4625 - val_accuracy: 0.8509 - val_loss: 0.4325 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.43254 to 0.37585, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 374ms/step - accuracy: 0.8534 - loss: 0.3705 - val_accuracy: 0.8816 - val_loss: 0.3759 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.37585
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 381ms/step - accuracy: 0.8641 - loss: 0.3509 - val_accuracy: 0.8640 - val_loss: 0.4137 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.37585 to 0.31115, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 362ms/step - accuracy: 0.8497 - loss: 0.3926 - val_accuracy: 0.8860 - val_loss: 0.3111 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.31115 to 0.29831, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 369ms/step - accuracy: 0.8881 - loss: 0.3025 - val_accuracy: 0.8882 - val_loss: 0.2983 - learning_rate: 0.0010
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.29831
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 403ms/step - accuracy: 0.8843 - loss: 0.3185 - val_accuracy: 0.8860 - val_loss: 0.3016 - learning_rate: 0.0010
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.29831
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 380ms/step - accuracy: 0.8937 - loss: 0.2873 - val_accuracy: 0.8969 - val_loss: 0.3274 - learning_rate: 0.0010
# Epoch 18/100
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 18: val_loss did not improve from 0.29831
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 367ms/step - accuracy: 0.8987 - loss: 0.2668 - val_accuracy: 0.8728 - val_loss: 0.3610 - learning_rate: 0.0010
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.29831 to 0.29662, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 375ms/step - accuracy: 0.9126 - loss: 0.2418 - val_accuracy: 0.9167 - val_loss: 0.2966 - learning_rate: 1.0000e-04
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.29662 to 0.28391, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 39s 379ms/step - accuracy: 0.9224 - loss: 0.2000 - val_accuracy: 0.9189 - val_loss: 0.2839 - learning_rate: 1.0000e-04
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.28391
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 366ms/step - accuracy: 0.9274 - loss: 0.1907 - val_accuracy: 0.9276 - val_loss: 0.2861 - learning_rate: 1.0000e-04
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.28391 to 0.27416, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 34s 332ms/step - accuracy: 0.9337 - loss: 0.1758 - val_accuracy: 0.9232 - val_loss: 0.2742 - learning_rate: 1.0000e-04
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.27416 to 0.26855, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_2.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 369ms/step - accuracy: 0.9320 - loss: 0.1728 - val_accuracy: 0.9254 - val_loss: 0.2686 - learning_rate: 1.0000e-04
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.26855
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 37s 359ms/step - accuracy: 0.9359 - loss: 0.1664 - val_accuracy: 0.9276 - val_loss: 0.2760 - learning_rate: 1.0000e-04
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.26855
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 37s 362ms/step - accuracy: 0.9310 - loss: 0.1660 - val_accuracy: 0.9211 - val_loss: 0.2727 - learning_rate: 1.0000e-04
# Epoch 26/100
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 26: val_loss did not improve from 0.26855
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 402ms/step - accuracy: 0.9339 - loss: 0.1650 - val_accuracy: 0.9211 - val_loss: 0.2764 - learning_rate: 1.0000e-04
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.26855
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 35s 341ms/step - accuracy: 0.9400 - loss: 0.1625 - val_accuracy: 0.9232 - val_loss: 0.2692 - learning_rate: 1.0000e-05
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.26855
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 37s 356ms/step - accuracy: 0.9398 - loss: 0.1659 - val_accuracy: 0.9232 - val_loss: 0.2725 - learning_rate: 1.0000e-05
# Epoch 29/100
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 29: val_loss did not improve from 0.26855
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 36s 347ms/step - accuracy: 0.9400 - loss: 0.1542 - val_accuracy: 0.9232 - val_loss: 0.2696 - learning_rate: 1.0000e-05
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.26855
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 362ms/step - accuracy: 0.9472 - loss: 0.1496 - val_accuracy: 0.9232 - val_loss: 0.2701 - learning_rate: 1.0000e-06
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 23.
# [INFO] Saved model for Fold 2 to greyColor_NoQuant_Attention_kfold_model_2.keras
# INFO:tensorflow:Assets written to: /tmp/tmpdnrife2a/assets
# INFO:tensorflow:Assets written to: /tmp/tmpdnrife2a/assets
# Saved artifact at '/tmp/tmpdnrife2a'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name='keras_tensor_38')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   139727232742032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232740688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232740880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232740112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232739920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232739344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232739152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232738576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232738384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232737808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232737616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232737040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232738192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232735504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232735888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139727232742416: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/srihari2895/TFProj/tfenv/lib/python3.12/site-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1754575954.140863     406 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1754575954.140946     406 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-08-07 14:12:34.141200: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmpdnrife2a
# 2025-08-07 14:12:34.141911: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-08-07 14:12:34.141922: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmpdnrife2a
# 2025-08-07 14:12:34.148199: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-08-07 14:12:34.185202: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmpdnrife2a
# 2025-08-07 14:12:34.195489: I tensorflow/cc/saved_model/loader.cc:466] SavedModel load for tags { serve }; Status: success: OK. Took 54291 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# /home/srihari2895/TFProj/tfenv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# [INFO] Saved quantized TFLite model for Fold 2 to NoQuant_Attention_kfold_model_2.tflite
#
# [INFO] Fold 3
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.91616, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_3.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 381ms/step - accuracy: 0.4193 - loss: 1.3297 - val_accuracy: 0.5877 - val_loss: 0.9162 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.91616 to 0.75664, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_3.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 363ms/step - accuracy: 0.6198 - loss: 0.8881 - val_accuracy: 0.6711 - val_loss: 0.7566 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.75664 to 0.61370, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_3.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 363ms/step - accuracy: 0.6941 - loss: 0.7590 - val_accuracy: 0.7632 - val_loss: 0.6137 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.61370 to 0.58805, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_3.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 357ms/step - accuracy: 0.7156 - loss: 0.6795 - val_accuracy: 0.7697 - val_loss: 0.5881 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.58805
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 37s 360ms/step - accuracy: 0.7547 - loss: 0.6162 - val_accuracy: 0.7478 - val_loss: 0.6108 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.58805 to 0.50944, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_3.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 37s 353ms/step - accuracy: 0.7653 - loss: 0.5841 - val_accuracy: 0.8004 - val_loss: 0.5094 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.50944
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 37s 361ms/step - accuracy: 0.7960 - loss: 0.5274 - val_accuracy: 0.7807 - val_loss: 0.5673 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.50944
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 36s 349ms/step - accuracy: 0.7808 - loss: 0.5505 - val_accuracy: 0.7610 - val_loss: 0.5125 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.50944 to 0.46221, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_3.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 37s 358ms/step - accuracy: 0.7962 - loss: 0.5136 - val_accuracy: 0.8202 - val_loss: 0.4622 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.46221 to 0.44785, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_3.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 37s 356ms/step - accuracy: 0.8049 - loss: 0.4894 - val_accuracy: 0.8136 - val_loss: 0.4479 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.44785 to 0.43484, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_3.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 363ms/step - accuracy: 0.8247 - loss: 0.4618 - val_accuracy: 0.8311 - val_loss: 0.4348 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.43484
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 365ms/step - accuracy: 0.8244 - loss: 0.4451 - val_accuracy: 0.8377 - val_loss: 0.4573 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.43484 to 0.38374, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_3.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 36s 345ms/step - accuracy: 0.8003 - loss: 0.4973 - val_accuracy: 0.8575 - val_loss: 0.3837 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.38374
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 37s 353ms/step - accuracy: 0.8162 - loss: 0.4643 - val_accuracy: 0.8355 - val_loss: 0.4479 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.38374
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 37s 355ms/step - accuracy: 0.8538 - loss: 0.3942 - val_accuracy: 0.8377 - val_loss: 0.4822 - learning_rate: 0.0010
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.38374 to 0.35817, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_3.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 370ms/step - accuracy: 0.8589 - loss: 0.3775 - val_accuracy: 0.8618 - val_loss: 0.3582 - learning_rate: 0.0010
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.35817 to 0.30577, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_3.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 38s 366ms/step - accuracy: 0.8696 - loss: 0.3608 - val_accuracy: 0.8882 - val_loss: 0.3058 - learning_rate: 0.0010
# Epoch 18/100
#
# ...
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.30566
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 43s 413ms/step - accuracy: 0.9405 - loss: 0.1632 - val_accuracy: 0.8969 - val_loss: 0.3066 - learning_rate: 1.0000e-06
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 33.
# [INFO] Saved model for Fold 8 to greyColor_NoQuant_Attention_kfold_model_8.keras
# INFO:tensorflow:Assets written to: /tmp/tmp0vtzf63e/assets
# INFO:tensorflow:Assets written to: /tmp/tmp0vtzf63e/assets
# Saved artifact at '/tmp/tmp0vtzf63e'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name='keras_tensor_152')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   139730300603088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725703499792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725710793552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725710795664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725823363600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725823363216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725830295376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725830298640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725830298832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725830299024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725830294800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725830291728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725830299408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725692466768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725692466576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725692458128: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/srihari2895/TFProj/tfenv/lib/python3.12/site-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1754584536.146636     406 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1754584536.146702     406 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-08-07 16:35:36.146964: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp0vtzf63e
# 2025-08-07 16:35:36.147705: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-08-07 16:35:36.147718: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmp0vtzf63e
# 2025-08-07 16:35:36.155675: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-08-07 16:35:36.207767: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmp0vtzf63e
# 2025-08-07 16:35:36.221092: I tensorflow/cc/saved_model/loader.cc:466] SavedModel load for tags { serve }; Status: success: OK. Took 74158 microseconds.
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# /home/srihari2895/TFProj/tfenv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# [INFO] Saved quantized TFLite model for Fold 8 to NoQuant_Attention_kfold_model_8.tflite
#
# [INFO] Fold 9
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 1.01992, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 50s 438ms/step - accuracy: 0.3812 - loss: 1.3813 - val_accuracy: 0.5614 - val_loss: 1.0199 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 1.01992 to 0.87706, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 387ms/step - accuracy: 0.5826 - loss: 0.9513 - val_accuracy: 0.6184 - val_loss: 0.8771 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.87706 to 0.81977, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 407ms/step - accuracy: 0.6337 - loss: 0.8211 - val_accuracy: 0.6404 - val_loss: 0.8198 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.81977 to 0.74105, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 382ms/step - accuracy: 0.6801 - loss: 0.7459 - val_accuracy: 0.7127 - val_loss: 0.7411 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.74105
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 381ms/step - accuracy: 0.7445 - loss: 0.6247 - val_accuracy: 0.6579 - val_loss: 0.8102 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.74105 to 0.63921, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 44s 407ms/step - accuracy: 0.7311 - loss: 0.6259 - val_accuracy: 0.7961 - val_loss: 0.6392 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.63921 to 0.58229, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 43s 420ms/step - accuracy: 0.7639 - loss: 0.5531 - val_accuracy: 0.7763 - val_loss: 0.5823 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.58229
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 41s 399ms/step - accuracy: 0.7881 - loss: 0.5182 - val_accuracy: 0.7719 - val_loss: 0.6073 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.58229 to 0.51544, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 407ms/step - accuracy: 0.7809 - loss: 0.5238 - val_accuracy: 0.8026 - val_loss: 0.5154 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.51544
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 40s 383ms/step - accuracy: 0.8088 - loss: 0.4736 - val_accuracy: 0.7763 - val_loss: 0.5372 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.51544
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 46s 443ms/step - accuracy: 0.8342 - loss: 0.4353 - val_accuracy: 0.8289 - val_loss: 0.5233 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 12: val_loss did not improve from 0.51544
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 50s 486ms/step - accuracy: 0.8283 - loss: 0.4253 - val_accuracy: 0.8114 - val_loss: 0.5267 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.51544 to 0.41673, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 51s 496ms/step - accuracy: 0.8513 - loss: 0.3885 - val_accuracy: 0.8596 - val_loss: 0.4167 - learning_rate: 1.0000e-04
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.41673 to 0.40767, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 47s 455ms/step - accuracy: 0.8773 - loss: 0.3206 - val_accuracy: 0.8706 - val_loss: 0.4077 - learning_rate: 1.0000e-04
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.40767
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 46s 444ms/step - accuracy: 0.8799 - loss: 0.3165 - val_accuracy: 0.8662 - val_loss: 0.4110 - learning_rate: 1.0000e-04
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.40767 to 0.39499, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 46s 449ms/step - accuracy: 0.8842 - loss: 0.3048 - val_accuracy: 0.8662 - val_loss: 0.3950 - learning_rate: 1.0000e-04
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.39499 to 0.36273, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 46s 441ms/step - accuracy: 0.8887 - loss: 0.3012 - val_accuracy: 0.8838 - val_loss: 0.3627 - learning_rate: 1.0000e-04
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.36273
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 43s 419ms/step - accuracy: 0.8878 - loss: 0.2930 - val_accuracy: 0.8794 - val_loss: 0.3633 - learning_rate: 1.0000e-04
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.36273 to 0.35561, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 46s 444ms/step - accuracy: 0.8863 - loss: 0.2885 - val_accuracy: 0.8882 - val_loss: 0.3556 - learning_rate: 1.0000e-04
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.35561 to 0.34421, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 43s 417ms/step - accuracy: 0.8983 - loss: 0.2627 - val_accuracy: 0.8925 - val_loss: 0.3442 - learning_rate: 1.0000e-04
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.34421
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 44s 425ms/step - accuracy: 0.8984 - loss: 0.2704 - val_accuracy: 0.8816 - val_loss: 0.3545 - learning_rate: 1.0000e-04
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.34421 to 0.33540, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 47s 452ms/step - accuracy: 0.9114 - loss: 0.2524 - val_accuracy: 0.8860 - val_loss: 0.3354 - learning_rate: 1.0000e-04
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.33540
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 45s 435ms/step - accuracy: 0.9070 - loss: 0.2496 - val_accuracy: 0.8816 - val_loss: 0.3376 - learning_rate: 1.0000e-04
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.33540 to 0.32955, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 43s 418ms/step - accuracy: 0.9011 - loss: 0.2538 - val_accuracy: 0.8860 - val_loss: 0.3296 - learning_rate: 1.0000e-04
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.32955 to 0.32741, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 45s 435ms/step - accuracy: 0.9081 - loss: 0.2301 - val_accuracy: 0.8838 - val_loss: 0.3274 - learning_rate: 1.0000e-04
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.32741
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 48s 461ms/step - accuracy: 0.9132 - loss: 0.2340 - val_accuracy: 0.8860 - val_loss: 0.3315 - learning_rate: 1.0000e-04
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.32741 to 0.31108, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_9.keras
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 48s 463ms/step - accuracy: 0.9077 - loss: 0.2447 - val_accuracy: 0.8969 - val_loss: 0.3111 - learning_rate: 1.0000e-04
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.31108
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 46s 444ms/step - accuracy: 0.9116 - loss: 0.2322 - val_accuracy: 0.8925 - val_loss: 0.3158 - learning_rate: 1.0000e-04
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.31108
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 47s 450ms/step - accuracy: 0.9126 - loss: 0.2261 - val_accuracy: 0.8991 - val_loss: 0.3418 - learning_rate: 1.0000e-04
# Epoch 30/100
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 30: val_loss did not improve from 0.31108
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 46s 448ms/step - accuracy: 0.9089 - loss: 0.2302 - val_accuracy: 0.8904 - val_loss: 0.3193 - learning_rate: 1.0000e-04
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.31108
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 45s 436ms/step - accuracy: 0.9197 - loss: 0.2182 - val_accuracy: 0.8947 - val_loss: 0.3127 - learning_rate: 1.0000e-05
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.31108
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 42s 405ms/step - accuracy: 0.9185 - loss: 0.2231 - val_accuracy: 0.8969 - val_loss: 0.3122 - learning_rate: 1.0000e-05
# Epoch 33/100
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 33: val_loss did not improve from 0.31108
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 44s 425ms/step - accuracy: 0.9187 - loss: 0.2173 - val_accuracy: 0.8947 - val_loss: 0.3162 - learning_rate: 1.0000e-05
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.31108
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 49s 477ms/step - accuracy: 0.9167 - loss: 0.2139 - val_accuracy: 0.8947 - val_loss: 0.3142 - learning_rate: 1.0000e-06
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 27.
# [INFO] Saved model for Fold 9 to greyColor_NoQuant_Attention_kfold_model_9.keras
# INFO:tensorflow:Assets written to: /tmp/tmp8r20ht2e/assets
# INFO:tensorflow:Assets written to: /tmp/tmp8r20ht2e/assets
# Saved artifact at '/tmp/tmp8r20ht2e'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name='keras_tensor_171')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   139729841608016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689454224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689453840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689453264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689453072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689452496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689452304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689451728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689451536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689450960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689450768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689450192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689450000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689448848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689448656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689449424: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/srihari2895/TFProj/tfenv/lib/python3.12/site-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1754586160.586670     406 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1754586160.586732     406 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-08-07 17:02:40.586998: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp8r20ht2e
# 2025-08-07 17:02:40.587663: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-08-07 17:02:40.587672: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmp8r20ht2e
# 2025-08-07 17:02:40.593689: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-08-07 17:02:40.635431: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmp8r20ht2e
# 2025-08-07 17:02:40.645095: I tensorflow/cc/saved_model/loader.cc:466] SavedModel load for tags { serve }; Status: success: OK. Took 58071 microseconds.
# [INFO] Saved quantized TFLite model for Fold 9 to NoQuant_Attention_kfold_model_9.tflite
# 2025-08-07 17:04:07.571173
# Difference in minutes:  439.0 minutes 13.642926000000443 seconds
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8

# %% [markdown]
# **MODEL PERFORMANCE**

# %%
import matplotlib.pyplot as plt
import json

n_splits = 10  # or whatever number of folds you used

# Create a single figure with 10 subplots (2 rows, 5 columns)
fig, axes = plt.subplots(2, 5, figsize=(20, 8))  # Adjust size as needed
axes = axes.flatten()  # Flatten for easier indexing

for fold in range(n_splits):
    with open(f"/mnt/c/modelFiles/10splitsFlatten/history_fold_{fold}.json", "r") as f:
        hist = json.load(f)

    ax = axes[fold]
    ax.plot(hist["accuracy"], label="Train Acc")
    ax.plot(hist["val_accuracy"], label="Val Acc")
    ax.set_title(f"Fold {fold}")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Accuracy")
    ax.legend()
    ax.grid(True)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.suptitle("Train vs Val Accuracy per Fold", fontsize=16, y=1.02)
plt.show()

# %%
import matplotlib.pyplot as plt
import json

n_splits = 10  # or whatever number of folds you used

# Create a single figure with 10 subplots (2 rows, 5 columns)
fig, axes = plt.subplots(2, 5, figsize=(20, 8))  # Adjust size as needed
axes = axes.flatten()  # Flatten for easier indexing

for fold in range(n_splits):
    with open(f"/mnt/c/modelFiles/10splitsFlatten/history_fold_{fold}.json", "r") as f:
        hist = json.load(f)

    ax = axes[fold]
    ax.plot(hist["loss"], label="Train loss")
    ax.plot(hist["val_loss"], label="Val loss")
    ax.set_title(f"Fold {fold}")
    ax.set_xlabel("Epoch")
    ax.set_ylabel("Loss")
    ax.legend()
    ax.grid(True)

# Adjust layout to prevent overlap
plt.tight_layout()
plt.suptitle("Train vs Val Accuracy per Fold", fontsize=16, y=1.02)
plt.show()

# %% [markdown]
# CHOOSING BEST MODEL - KERAS

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from tensorflow.keras.models import load_model

# Load all 10 Keras models
model_paths = [f"/mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_{fold}.keras" for fold in range(10)]
models = [load_model(path) for path in model_paths]

def evaluate_individual_models(models, test_generator):
    class_names = list(test_generator.class_indices.keys())
    num_samples = len(test_generator.image_paths)
    steps = int(np.ceil(num_samples / test_generator.batch_size))
    f1_scores = []

    for model_idx, model in enumerate(models):
        y_true_all, y_pred_all = [], []
        test_generator.reset()

        for _ in range(steps):
            x_batch, y_batch = next(test_generator)
            preds = model.predict(x_batch, verbose=0)
            y_pred_all.extend(np.argmax(preds, axis=1))
            y_true_all.extend(np.argmax(y_batch, axis=1))

        y_true_all = np.array(y_true_all[:num_samples])
        y_pred_all = np.array(y_pred_all[:num_samples])

        print(f"\n=== Model {model_idx + 1} ===")
        print("Classification Report:")
        print(classification_report(y_true_all, y_pred_all, target_names=class_names))

        # F1-score (weighted)
        f1 = f1_score(y_true_all, y_pred_all, average='weighted')
        f1_scores.append(f1)

        accuracy = np.mean(y_true_all == y_pred_all)
        print(f"Model {model_idx + 1} Accuracy: {accuracy:.4f}")
        print(f"Model {model_idx + 1} Weighted F1-Score: {f1:.4f}")

        print("Per-class Accuracy:")
        for i, class_name in enumerate(class_names):
            mask = y_true_all == i
            correct = np.sum((y_true_all == i) & (y_pred_all == i))
            acc = correct / np.sum(mask) if np.sum(mask) > 0 else 0.0
            print(f"{class_name}: {acc:.4f}")

    # --- Plot F1-Scores ---
    plt.figure(figsize=(10, 5))
    bars = plt.bar(range(len(models)), f1_scores, color='skyblue')
    plt.title('F1-Scores of 10 Keras Models')
    plt.xlabel('Model Index')
    plt.ylabel('F1-Score (Weighted)')
    plt.ylim(0, 1.05)
    plt.xticks(range(10), [f'Model {i}' for i in range(10)])

    # Annotate each bar with F1-score
    for bar, score in zip(bars, f1_scores):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01,
                 f'{score:.2f}', ha='center', va='bottom', fontsize=10)

    plt.tight_layout()
    plt.savefig("keras_f1_scores.png")
    plt.show()

# Run the evaluation and plot
evaluate_individual_models(models, test_generator)
# Out:
# === Model 1 ===
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.94      0.97      0.96        70
# horizontal_line       0.91      0.85      0.88        34
#           stain       0.97      1.00      0.98        32
#            tear       0.87      0.94      0.91        71
#   vertical_line       0.92      0.73      0.81        33
#
#        accuracy                           0.92       240
#       macro avg       0.92      0.90      0.91       240
#    weighted avg       0.92      0.92      0.91       240
#
# Model 1 Accuracy: 0.9167
# Model 1 Weighted F1-Score: 0.9148
# Per-class Accuracy:
# No_Defect: 0.9714
# horizontal_line: 0.8529
# stain: 1.0000
# tear: 0.9437
# vertical_line: 0.7273
#
# === Model 2 ===
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.99      0.99      0.99        70
# horizontal_line       0.90      0.82      0.86        34
#           stain       1.00      1.00      1.00        32
#            tear       0.89      0.90      0.90        71
#   vertical_line       0.74      0.79      0.76        33
#
#        accuracy                           0.91       240
#       macro avg       0.90      0.90      0.90       240
#    weighted avg       0.91      0.91      0.91       240
#
# Model 2 Accuracy: 0.9125
# Model 2 Weighted F1-Score: 0.9128
# Per-class Accuracy:
# No_Defect: 0.9857
# horizontal_line: 0.8235
# stain: 1.0000
# tear: 0.9014
# vertical_line: 0.7879
#
# === Model 3 ===
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.93      0.97      0.95        70
# horizontal_line       0.95      0.62      0.75        34
#           stain       1.00      1.00      1.00        32
#            tear       0.88      0.93      0.90        71
#   vertical_line       0.63      0.73      0.68        33
#
#        accuracy                           0.88       240
#       macro avg       0.88      0.85      0.86       240
#    weighted avg       0.89      0.88      0.88       240
#
# Model 3 Accuracy: 0.8792
# Model 3 Weighted F1-Score: 0.8774
# Per-class Accuracy:
# No_Defect: 0.9714
# horizontal_line: 0.6176
# stain: 1.0000
# tear: 0.9296
# vertical_line: 0.7273
#
# === Model 4 ===
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.99      1.00      0.99        70
# horizontal_line       0.81      0.85      0.83        34
#           stain       1.00      1.00      1.00        32
#            tear       0.92      0.93      0.92        71
#   vertical_line       0.79      0.70      0.74        33
#
#        accuracy                           0.92       240
#       macro avg       0.90      0.90      0.90       240
#    weighted avg       0.92      0.92      0.92       240
#
# Model 4 Accuracy: 0.9167
# Model 4 Weighted F1-Score: 0.9154
# Per-class Accuracy:
# No_Defect: 1.0000
# horizontal_line: 0.8529
# stain: 1.0000
# tear: 0.9296
# vertical_line: 0.6970
#
# === Model 5 ===
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.97      0.91      0.94        70
# horizontal_line       0.85      0.82      0.84        34
#           stain       1.00      1.00      1.00        32
#            tear       0.84      0.90      0.87        71
#   vertical_line       0.61      0.61      0.61        33
#
#        accuracy                           0.87       240
#       macro avg       0.85      0.85      0.85       240
#    weighted avg       0.87      0.87      0.87       240
#
# Model 5 Accuracy: 0.8667
# Model 5 Weighted F1-Score: 0.8672
# Per-class Accuracy:
# No_Defect: 0.9143
# horizontal_line: 0.8235
# stain: 1.0000
# tear: 0.9014
# vertical_line: 0.6061
#
# === Model 6 ===
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.99      0.99      0.99        70
# horizontal_line       0.88      0.82      0.85        34
#           stain       1.00      1.00      1.00        32
#            tear       0.88      0.92      0.90        71
#   vertical_line       0.78      0.76      0.77        33
#
#        accuracy                           0.91       240
#       macro avg       0.90      0.90      0.90       240
#    weighted avg       0.91      0.91      0.91       240
#
# Model 6 Accuracy: 0.9125
# Model 6 Weighted F1-Score: 0.9120
# Per-class Accuracy:
# No_Defect: 0.9857
# horizontal_line: 0.8235
# stain: 1.0000
# tear: 0.9155
# vertical_line: 0.7576
#
# === Model 7 ===
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.99      0.99      0.99        70
# horizontal_line       0.77      0.79      0.78        34
#           stain       1.00      1.00      1.00        32
#            tear       0.93      0.92      0.92        71
#   vertical_line       0.73      0.73      0.73        33
#
#        accuracy                           0.90       240
#       macro avg       0.88      0.88      0.88       240
#    weighted avg       0.90      0.90      0.90       240
#
# Model 7 Accuracy: 0.9042
# Model 7 Weighted F1-Score: 0.9045
# Per-class Accuracy:
# No_Defect: 0.9857
# horizontal_line: 0.7941
# stain: 1.0000
# tear: 0.9155
# vertical_line: 0.7273
#
# === Model 8 ===
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.97      0.94      0.96        70
# horizontal_line       0.80      0.82      0.81        34
#           stain       1.00      1.00      1.00        32
#            tear       0.87      0.92      0.89        71
#   vertical_line       0.70      0.64      0.67        33
#
#        accuracy                           0.88       240
#       macro avg       0.87      0.86      0.87       240
#    weighted avg       0.88      0.88      0.88       240
#
# Model 8 Accuracy: 0.8833
# Model 8 Weighted F1-Score: 0.8824
# Per-class Accuracy:
# No_Defect: 0.9429
# horizontal_line: 0.8235
# stain: 1.0000
# tear: 0.9155
# vertical_line: 0.6364
#
# === Model 9 ===
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.96      0.99      0.97        70
# horizontal_line       0.77      0.71      0.74        34
#           stain       0.97      1.00      0.98        32
#            tear       0.86      0.90      0.88        71
#   vertical_line       0.67      0.61      0.63        33
#
#        accuracy                           0.87       240
#       macro avg       0.85      0.84      0.84       240
#    weighted avg       0.87      0.87      0.87       240
#
# Model 9 Accuracy: 0.8708
# Model 9 Weighted F1-Score: 0.8678
# Per-class Accuracy:
# No_Defect: 0.9857
# horizontal_line: 0.7059
# stain: 1.0000
# tear: 0.9014
# vertical_line: 0.6061
#
# === Model 10 ===
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.96      0.96      0.96        70
# horizontal_line       0.90      0.76      0.83        34
#           stain       1.00      1.00      1.00        32
#            tear       0.87      0.93      0.90        71
#   vertical_line       0.67      0.67      0.67        33
#
#        accuracy                           0.89       240
#       macro avg       0.88      0.86      0.87       240
#    weighted avg       0.89      0.89      0.89       240
#
# Model 10 Accuracy: 0.8875
# Model 10 Weighted F1-Score: 0.8867
# Per-class Accuracy:
# No_Defect: 0.9571
# horizontal_line: 0.7647
# stain: 1.0000
# tear: 0.9296
# vertical_line: 0.6667

# %% [markdown]
# CHOOSING BEST MODEL - TFLite

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, f1_score

# Paths to the 10 TFLite models
tflite_model_paths = [f"/mnt/c/modelFiles/10splitsFlatten/NoQuant_Attention_kfold_model_{fold}.tflite" for fold in range(10)]

# Load all interpreters
interpreters = []
input_details_list = []
output_details_list = []
quant_params_list = []

for path in tflite_model_paths:
    interpreter = tf.lite.Interpreter(model_path=path)
    interpreter.allocate_tensors()
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    scale, zero_point = input_details[0]['quantization']

    interpreters.append(interpreter)
    input_details_list.append(input_details)
    output_details_list.append(output_details)
    quant_params_list.append((scale, zero_point))

# Evaluate each model and store F1-scores
f1_scores = []

print(f"\nRunning evaluation for {len(interpreters)} individual TFLite models...\n")

for model_idx in range(len(interpreters)):
    y_true = []
    y_pred = []

    print(f"\n--- Evaluating TFLite Model {model_idx + 1} ---")

    for batch_images, batch_labels in test_generator:
        for img, label in zip(batch_images, batch_labels):
            img = np.expand_dims(img, axis=0).astype(np.float32)

            scale, zero_point = quant_params_list[model_idx]
            img_int8 = (img / scale + zero_point).astype(np.int8)

            interpreters[model_idx].set_tensor(input_details_list[model_idx][0]['index'], img_int8)
            interpreters[model_idx].invoke()
            output_data = interpreters[model_idx].get_tensor(output_details_list[model_idx][0]['index'])

            pred_class = np.argmax(output_data[0])
            true_class = np.argmax(label)

            y_pred.append(pred_class)
            y_true.append(true_class)

    f1 = f1_score(y_true, y_pred, average='weighted')
    f1_scores.append(f1)

    print(f"Model {model_idx + 1} Weighted F1-Score: {f1:.4f}")
    print("Classification Report:")
    target_names = list(label_encoder.classes_)  # assumes a fitted label_encoder
    print(classification_report(y_true, y_pred, target_names=target_names))

# --- Plot F1-Scores ---
plt.figure(figsize=(10, 5))
bars = plt.bar(range(10), f1_scores, color='orange')
plt.title('F1-Scores of 10 TFLite Models')
plt.xlabel('Model Index')
plt.ylabel('F1-Score (Weighted)')
plt.ylim(0, 1.05)
plt.xticks(range(10), [f'Model {i}' for i in range(10)])

# Annotate each bar with F1-score
for bar, score in zip(bars, f1_scores):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01,
             f'{score:.2f}', ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.savefig("tflite_f1_scores.png")
plt.show()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Running evaluation for 10 individual TFLite models...
#
#
# --- Evaluating TFLite Model 1 ---
# Model 1 Weighted F1-Score: 0.8875
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.92      1.00      0.96        70
# horizontal_line       0.79      0.76      0.78        34
#           stain       0.97      1.00      0.98        32
#            tear       0.88      0.92      0.90        71
#   vertical_line       0.88      0.64      0.74        33
#
#        accuracy                           0.89       240
#       macro avg       0.89      0.86      0.87       240
#    weighted avg       0.89      0.89      0.89       240
#
#
# --- Evaluating TFLite Model 2 ---
# Model 2 Weighted F1-Score: 0.9038
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.99      0.99      0.99        70
# horizontal_line       0.87      0.76      0.81        34
#           stain       1.00      1.00      1.00        32
#            tear       0.89      0.93      0.91        71
#   vertical_line       0.71      0.73      0.72        33
#
#        accuracy                           0.90       240
#       macro avg       0.89      0.88      0.88       240
#    weighted avg       0.90      0.90      0.90       240
#
#
# --- Evaluating TFLite Model 3 ---
# Model 3 Weighted F1-Score: 0.8884
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.93      0.99      0.96        70
# horizontal_line       0.88      0.68      0.77        34
#           stain       1.00      1.00      1.00        32
#            tear       0.88      0.94      0.91        71
#   vertical_line       0.72      0.70      0.71        33
#
#        accuracy                           0.89       240
#       macro avg       0.88      0.86      0.87       240
#    weighted avg       0.89      0.89      0.89       240
#
#
# --- Evaluating TFLite Model 4 ---
# Model 4 Weighted F1-Score: 0.9195
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.99      1.00      0.99        70
# horizontal_line       0.81      0.85      0.83        34
#           stain       1.00      1.00      1.00        32
#            tear       0.93      0.94      0.94        71
#   vertical_line       0.79      0.70      0.74        33
#
#        accuracy                           0.92       240
#       macro avg       0.90      0.90      0.90       240
#    weighted avg       0.92      0.92      0.92       240
#
#
# --- Evaluating TFLite Model 5 ---
# Model 5 Weighted F1-Score: 0.8790
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.96      0.96      0.96        70
# horizontal_line       0.78      0.82      0.80        34
#           stain       1.00      1.00      1.00        32
#            tear       0.87      0.94      0.91        71
#   vertical_line       0.72      0.55      0.62        33
#
#        accuracy                           0.88       240
#       macro avg       0.87      0.85      0.86       240
#    weighted avg       0.88      0.88      0.88       240
#
#
# --- Evaluating TFLite Model 6 ---
# Model 6 Weighted F1-Score: 0.9014
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.97      1.00      0.99        70
# horizontal_line       0.85      0.85      0.85        34
#           stain       1.00      1.00      1.00        32
#            tear       0.87      0.92      0.89        71
#   vertical_line       0.78      0.64      0.70        33
#
#        accuracy                           0.90       240
#       macro avg       0.89      0.88      0.89       240
#    weighted avg       0.90      0.90      0.90       240
#
#
# --- Evaluating TFLite Model 7 ---
# Model 7 Weighted F1-Score: 0.9070
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.99      0.99      0.99        70
# horizontal_line       0.77      0.88      0.82        34
#           stain       1.00      1.00      1.00        32
#            tear       0.90      0.92      0.91        71
#   vertical_line       0.81      0.67      0.73        33
#
#        accuracy                           0.91       240
#       macro avg       0.89      0.89      0.89       240
#    weighted avg       0.91      0.91      0.91       240
#
#
# --- Evaluating TFLite Model 8 ---
# Model 8 Weighted F1-Score: 0.8842
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.97      0.99      0.98        70
# horizontal_line       0.82      0.82      0.82        34
#           stain       1.00      1.00      1.00        32
#            tear       0.86      0.92      0.88        71
#   vertical_line       0.70      0.58      0.63        33
#
#        accuracy                           0.89       240
#       macro avg       0.87      0.86      0.86       240
#    weighted avg       0.88      0.89      0.88       240
#
#
# --- Evaluating TFLite Model 9 ---
# Model 9 Weighted F1-Score: 0.8779
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.95      1.00      0.97        70
# horizontal_line       0.79      0.79      0.79        34
#           stain       0.97      1.00      0.98        32
#            tear       0.88      0.92      0.90        71
#   vertical_line       0.72      0.55      0.62        33
#
#        accuracy                           0.88       240
#       macro avg       0.86      0.85      0.85       240
#    weighted avg       0.88      0.88      0.88       240
#
#
# --- Evaluating TFLite Model 10 ---
# Model 10 Weighted F1-Score: 0.8645
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.94      0.96      0.95        70
# horizontal_line       0.83      0.74      0.78        34
#           stain       1.00      1.00      1.00        32
#            tear       0.86      0.92      0.88        71
#   vertical_line       0.61      0.58      0.59        33
#
#        accuracy                           0.87       240
#       macro avg       0.85      0.84      0.84       240
#    weighted avg       0.86      0.87      0.86       240

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array

X_train = all_filepaths
y_train = all_labels

def preprocess_image(path, label):
    img = load_img(path.decode(), target_size=IMG_SIZE, color_mode='grayscale')
    img = img_to_array(img) / 255.0
    return img, label

def tf_preprocess(path, label):
    img, lbl = tf.py_function(preprocess_image, [path, label], [tf.float32, tf.int64])
    img.set_shape((IMG_SIZE[0], IMG_SIZE[1], 1))
    lbl.set_shape(())
    return img, lbl

# Use full dataset for training
X_train = all_filepaths
y_train = all_labels

# Create the custom data generator using 100% of data
train_generator = CustomDataGenerator(
    image_paths=X_train,
    labels=y_train,
    batch_size=BATCH_SIZE,
    img_size=IMG_SIZE,
    num_classes=NUM_CLASSES,
    shuffle=True,
    class_indices=class_indices
)

# %%
model = create_cnn_model_with_attention(INPUT_SHAPE, NUM_CLASSES)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
train_generator = CustomDataGenerator(X_train_main, y_train_main, BATCH_SIZE, IMG_SIZE, NUM_CLASSES,class_indices=class_indices)
test_generator = CustomDataGenerator( X_test_final, y_test_final, BATCH_SIZE, IMG_SIZE, NUM_CLASSES, shuffle=False,class_indices=class_indices)
# %%

# %%
with tf.device('/GPU:0'):
        history = model.fit(
            train_generator,
            validation_data=test_generator,
            epochs=EPOCHS,
            callbacks=[early_stopping, lr_scheduler, ModelCheckpoint("/mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras", monitor='val_loss', save_best_only=True, verbose=1), stop_at_100],
            verbose=1
        )

converter = tf.lite.TFLiteConverter.from_keras_model(model)
print("converter set")
# Enable full integer quantization
converter.optimizations = [tf.lite.Optimize.DEFAULT]
print("optimizations initialized")
# Define a representative dataset function for calibration
def representative_dataset_gen():
    for i in range(100):  # Just use first 100 images for calibration
        img, _ = train_generator[i]
        for x in img:
            yield [np.expand_dims(x, axis=0).astype(np.float32)]


converter.representative_dataset = representative_dataset_gen
print("representative dataset initialized")
# Ensure all tensors are int8
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8
print("type bit converstions done")
# Perform conversion
quantized_tflite_model = converter.convert()
print("quantized model obtained")
# Save the quantized model to disk
with open(f"/mnt/c/modelFiles/10splitsFlatten/tflite_NoQuant_Attention_final.tflite", "wb") as f:
    f.write(quantized_tflite_model)
print("tfmodel saved")
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.87885, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 49s 427ms/step - accuracy: 0.5833 - loss: 0.9772 - val_accuracy: 0.6250 - val_loss: 0.8788 - learning_rate: 0.0010
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.87885 to 0.81305, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 47s 405ms/step - accuracy: 0.6610 - loss: 0.8186 - val_accuracy: 0.6542 - val_loss: 0.8130 - learning_rate: 0.0010
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.81305 to 0.61584, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 49s 431ms/step - accuracy: 0.7239 - loss: 0.7016 - val_accuracy: 0.7583 - val_loss: 0.6158 - learning_rate: 0.0010
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.61584 to 0.56376, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 48s 418ms/step - accuracy: 0.7515 - loss: 0.6240 - val_accuracy: 0.8000 - val_loss: 0.5638 - learning_rate: 0.0010
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.56376
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 50s 433ms/step - accuracy: 0.7677 - loss: 0.5721 - val_accuracy: 0.7000 - val_loss: 0.6647 - learning_rate: 0.0010
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.56376
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 48s 421ms/step - accuracy: 0.7840 - loss: 0.5416 - val_accuracy: 0.7333 - val_loss: 0.5899 - learning_rate: 0.0010
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.56376 to 0.55017, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 50s 432ms/step - accuracy: 0.7871 - loss: 0.5473 - val_accuracy: 0.7917 - val_loss: 0.5502 - learning_rate: 0.0010
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.55017
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 46s 400ms/step - accuracy: 0.7969 - loss: 0.4953 - val_accuracy: 0.7750 - val_loss: 0.5965 - learning_rate: 0.0010
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.55017
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 46s 402ms/step - accuracy: 0.8266 - loss: 0.4438 - val_accuracy: 0.7792 - val_loss: 0.5519 - learning_rate: 0.0010
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.55017 to 0.48842, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 48s 421ms/step - accuracy: 0.8200 - loss: 0.4609 - val_accuracy: 0.8250 - val_loss: 0.4884 - learning_rate: 0.0010
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.48842
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 49s 428ms/step - accuracy: 0.8543 - loss: 0.3926 - val_accuracy: 0.7917 - val_loss: 0.5753 - learning_rate: 0.0010
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.48842 to 0.47261, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 47s 413ms/step - accuracy: 0.8342 - loss: 0.4313 - val_accuracy: 0.8208 - val_loss: 0.4726 - learning_rate: 0.0010
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.47261 to 0.41172, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 49s 425ms/step - accuracy: 0.8584 - loss: 0.3728 - val_accuracy: 0.8292 - val_loss: 0.4117 - learning_rate: 0.0010
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.41172 to 0.37643, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 48s 421ms/step - accuracy: 0.8813 - loss: 0.3203 - val_accuracy: 0.8542 - val_loss: 0.3764 - learning_rate: 0.0010
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.37643
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 50s 435ms/step - accuracy: 0.8811 - loss: 0.3140 - val_accuracy: 0.8500 - val_loss: 0.4369 - learning_rate: 0.0010
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.37643 to 0.32568, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 51s 447ms/step - accuracy: 0.8946 - loss: 0.3085 - val_accuracy: 0.9000 - val_loss: 0.3257 - learning_rate: 0.0010
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.32568 to 0.30445, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 48s 417ms/step - accuracy: 0.9147 - loss: 0.2376 - val_accuracy: 0.8833 - val_loss: 0.3045 - learning_rate: 0.0010
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.30445
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 51s 450ms/step - accuracy: 0.8972 - loss: 0.2785 - val_accuracy: 0.8542 - val_loss: 0.3487 - learning_rate: 0.0010
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.30445 to 0.27712, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 50s 432ms/step - accuracy: 0.9175 - loss: 0.2340 - val_accuracy: 0.9000 - val_loss: 0.2771 - learning_rate: 0.0010
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.27712
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 45s 395ms/step - accuracy: 0.9201 - loss: 0.2024 - val_accuracy: 0.8875 - val_loss: 0.2970 - learning_rate: 0.0010
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.27712
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 46s 398ms/step - accuracy: 0.9264 - loss: 0.2112 - val_accuracy: 0.8708 - val_loss: 0.3381 - learning_rate: 0.0010
# Epoch 22/100
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 22: val_loss did not improve from 0.27712
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 45s 396ms/step - accuracy: 0.9246 - loss: 0.2020 - val_accuracy: 0.8875 - val_loss: 0.2880 - learning_rate: 0.0010
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.27712 to 0.23538, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 46s 399ms/step - accuracy: 0.9524 - loss: 0.1314 - val_accuracy: 0.9083 - val_loss: 0.2354 - learning_rate: 1.0000e-04
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.23538
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 44s 380ms/step - accuracy: 0.9547 - loss: 0.1179 - val_accuracy: 0.9042 - val_loss: 0.2416 - learning_rate: 1.0000e-04
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.23538 to 0.22411, saving model to /mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 44s 386ms/step - accuracy: 0.9669 - loss: 0.0978 - val_accuracy: 0.9167 - val_loss: 0.2241 - learning_rate: 1.0000e-04
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.22411
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 44s 387ms/step - accuracy: 0.9587 - loss: 0.1169 - val_accuracy: 0.9125 - val_loss: 0.2367 - learning_rate: 1.0000e-04
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.22411
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 44s 379ms/step - accuracy: 0.9658 - loss: 0.1089 - val_accuracy: 0.9167 - val_loss: 0.2381 - learning_rate: 1.0000e-04
# Epoch 28/100
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 28: val_loss did not improve from 0.22411
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 44s 388ms/step - accuracy: 0.9624 - loss: 0.1095 - val_accuracy: 0.9250 - val_loss: 0.2395 - learning_rate: 1.0000e-04
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.22411
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 46s 399ms/step - accuracy: 0.9632 - loss: 0.1016 - val_accuracy: 0.9167 - val_loss: 0.2381 - learning_rate: 1.0000e-05
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.22411
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 46s 400ms/step - accuracy: 0.9667 - loss: 0.0941 - val_accuracy: 0.9208 - val_loss: 0.2391 - learning_rate: 1.0000e-05
# Epoch 31/100
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 31: val_loss did not improve from 0.22411
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 43s 374ms/step - accuracy: 0.9654 - loss: 0.1013 - val_accuracy: 0.9167 - val_loss: 0.2391 - learning_rate: 1.0000e-05
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.22411
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 42s 365ms/step - accuracy: 0.9628 - loss: 0.1010 - val_accuracy: 0.9167 - val_loss: 0.2392 - learning_rate: 1.0000e-06
# Epoch 32: early stopping
# Restoring model weights from the end of the best epoch: 25.
# converter set
# optimizations initialized
# representative dataset initialized
# type bit converstions done
# INFO:tensorflow:Assets written to: /tmp/tmp2ou8_c74/assets
# INFO:tensorflow:Assets written to: /tmp/tmp2ou8_c74/assets
# Saved artifact at '/tmp/tmp2ou8_c74'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name='keras_tensor_560')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   139724212783248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139724214465744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139733892091728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725485163920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139724214465936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725700895888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725700893776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689442512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725700892624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725689438480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725472742288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725472739600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725472740752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725472735568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725472734800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139725472736912: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/srihari2895/TFProj/tfenv/lib/python3.12/site-packages/tensorflow/lite/python/convert.py:997: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1754589457.950930     406 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1754589457.951054     406 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-08-07 17:57:37.951770: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmp2ou8_c74
# 2025-08-07 17:57:37.952346: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-08-07 17:57:37.952356: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmp2ou8_c74
# 2025-08-07 17:57:37.957911: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-08-07 17:57:38.000175: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmp2ou8_c74
# 2025-08-07 17:57:38.010761: I tensorflow/cc/saved_model/loader.cc:466] SavedModel load for tags { serve }; Status: success: OK. Took 58995 microseconds.
# quantized model obtained
# tfmodel saved
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8

# %% [markdown]
# **QUANTIZED MODEL EVALUATION**

# %% [markdown]
# .tflite Model

# %%
import tensorflow as tf
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Path to the TFLite model
model_path = "/mnt/c/modelFiles/10splitsFlatten/tflite_NoQuant_Attention_final.tflite" 

# Load interpreter
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
scale, zero_point = input_details[0]['quantization']

# Inference
y_true = []
y_pred = []

print("\nRunning prediction using TFLite model...\n")

for batch_images, batch_labels in test_generator:
    for img, label in zip(batch_images, batch_labels):
        img = np.expand_dims(img, axis=0).astype(np.float32)  # [1, H, W, C]

        img_int8 = (img / scale + zero_point).astype(np.int8)

        interpreter.set_tensor(input_details[0]['index'], img_int8)
        interpreter.invoke()
        output_data = interpreter.get_tensor(output_details[0]['index'])

        pred_class = np.argmax(output_data[0])
        true_class = np.argmax(label)

        y_pred.append(pred_class)
        y_true.append(true_class)

# Evaluation
print("TFLite Model Accuracy:", np.mean(np.array(y_true) == np.array(y_pred)))

# Classification report
target_names = list(label_encoder.classes_)  # assumes you have a fitted label_encoder
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=target_names))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges',
            xticklabels=target_names, yticklabels=target_names)
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.tight_layout()
plt.show()
# Out:
# Running prediction using TFLite model...
#
# TFLite Model Accuracy: 0.9208333333333333
#
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.97      0.99      0.98        70
# horizontal_line       0.86      0.88      0.87        34
#           stain       1.00      1.00      1.00        32
#            tear       0.90      0.92      0.91        71
#   vertical_line       0.83      0.76      0.79        33
#
#        accuracy                           0.92       240
#       macro avg       0.91      0.91      0.91       240
#    weighted avg       0.92      0.92      0.92       240

# %% [markdown]
# ***KERAS MODEL EVALUATION***

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import load_model

# Load one model 
model_path = "/mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Attention_kfold_model_final.keras"
model = load_model(model_path)

# %%
def evaluate_single_model(model, test_generator):
    num_samples = len(test_generator.image_paths)
    steps = int(np.ceil(num_samples / test_generator.batch_size))

    y_true_all, y_pred_all = [], []

    for _ in range(steps):
        x_batch, y_batch = next(test_generator)
        preds = model.predict(x_batch, verbose=0)
        y_pred_all.extend(np.argmax(preds, axis=1))
        y_true_all.extend(np.argmax(y_batch, axis=1))

    y_true_all = np.array(y_true_all[:num_samples])
    y_pred_all = np.array(y_pred_all[:num_samples])

    class_names = list(test_generator.class_indices.keys())

    # Confusion matrix
    cm = confusion_matrix(y_true_all, y_pred_all)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges',
                xticklabels=class_names,
                yticklabels=class_names)
    plt.title('Confusion Matrix - Single Model')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.tight_layout()
    plt.show()

    # Metrics
    print("\nClassification Report:")
    print(classification_report(y_true_all, y_pred_all, target_names=class_names))

    accuracy = np.sum(y_true_all == y_pred_all) / len(y_true_all)
    print(f"\nOverall Accuracy: {accuracy:.4f}")

    print("\nPer-class Accuracy:")
    for i, class_name in enumerate(class_names):
        mask = y_true_all == i
        correct = np.sum((y_true_all == i) & (y_pred_all == i))
        acc = correct / np.sum(mask) if np.sum(mask) > 0 else 0.0
        print(f"{class_name}: {acc:.4f}")

# Usage
evaluate_single_model(model, test_generator)
# Out:
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.99      0.99      0.99        70
# horizontal_line       0.93      0.82      0.88        34
#           stain       1.00      1.00      1.00        32
#            tear       0.89      0.92      0.90        71
#   vertical_line       0.74      0.79      0.76        33
#
#        accuracy                           0.92       240
#       macro avg       0.91      0.90      0.91       240
#    weighted avg       0.92      0.92      0.92       240
#
#
# Overall Accuracy: 0.9167
#
# Per-class Accuracy:
# No_Defect: 0.9857
# horizontal_line: 0.8235
# stain: 1.0000
# tear: 0.9155
# vertical_line: 0.7879

# %% [markdown]
# (SIMULATION)
# **COMPARISON BETWEEN A GENERIC MODEL AND QUANTIZATION AWARE TRAINING MODEL**

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Load both models
model_path = "/mnt/c/modelFiles/10splitsFlatten/tflite_NoQuant_Attention_SP_model.tflite" 

original_model = tf.keras.models.load_model("/mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_kfold_model_4.keras")
quantized_model = tf.keras.models.load_model("/mnt/c/modelFiles/10splitsFlatten/greyColor_quantized_kfold_model_0.keras", custom_objects=custom_objects)

# Build models if they aren't already
sample_input_shape = (None, 256, 256, 1)
original_model.build(input_shape=sample_input_shape)
quantized_model.build(input_shape=sample_input_shape)

# Extract weights for all convolutional layers
def get_all_conv_weights(model):
    weights = []
    for layer in model.layers:
        if isinstance(layer, (tf.keras.layers.Conv2D, QuantizedConv2D)):
            w = layer.get_weights()
            if w:
                weights.append(w[0])  # Only use kernel weights
    return weights

orig_weights_list = get_all_conv_weights(original_model)
quant_weights_list = get_all_conv_weights(quantized_model)

# Sanity check
num_layers = min(len(orig_weights_list), len(quant_weights_list))
print(f"Comparing {num_layers} convolutional layers")

# Plot distributions for each layer
for i in range(num_layers):
    orig_weights = orig_weights_list[i].flatten()
    quant_weights = quant_weights_list[i].flatten()
    
    plt.figure(figsize=(15, 4))
    
    plt.subplot(1, 3, 1)
    plt.hist(orig_weights, bins=50, alpha=0.6, label='Original')
    plt.title(f'Layer {i+1} Original Weights')
    plt.xlabel('Weight Value')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 2)
    plt.hist(quant_weights, bins=50, alpha=0.6, label='Quantized', color='orange')
    plt.title(f'Layer {i+1} Quantized Weights')
    plt.xlabel('Weight Value')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 3)
    plt.hist(orig_weights, bins=50, alpha=0.5, label='Original')
    plt.hist(quant_weights, bins=50, alpha=0.5, label='Quantized')
    plt.title(f'Layer {i+1} Overlaid Distribution')
    plt.xlabel('Weight Value')
    plt.ylabel('Frequency')
    plt.legend()
    
    plt.tight_layout()
    plt.savefig(f'conv_layer_{i+1}_weight_distribution_comparison.png')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 9
#       6 model_path = "/mnt/c/modelFiles/10splitsFlatten/tflite_NoQuant_Attention_SP_model.tflite"
#       8 original_model = tf.keras.models.load_model("/mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Atention_SP_model.keras")
# ----> 9 quantized_model = tf.keras.models.load_model("/mnt/c/modelFiles/10splitsFlatten/tflite_NoQuant_Attention_SP_model.tflite", custom_objects=custom_objects)
#      11 # Build models if they aren't already
#      12 sample_input_shape = (None, 256, 256, 1)
#
# File ~/TFProj/tfenv/lib/python3.12/site-packages/keras/src/saving/saving_api.py:206, in load_model(filepath, custom_objects, compile, safe_mode)
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#     205 else:
# --> 206     raise ValueError(
#     207         f"File format not supported: filepath={filepath}. "
#     208         "Keras 3 only supports V3 `.keras` files and "
#     209         "legacy H5 format files (`.h5` extension). "
#     210         "Note that the legacy SavedModel format is not "
#     211         "supported by `load_model()` in Keras 3. In "
#     212         "order to reload a TensorFlow SavedModel as an "
#     213         "inference-only layer in Keras 3, use "
#     214         "`keras.layers.TFSMLayer("
#     215         f"{filepath}, call_endpoint='serving_default')` "
#     216         "(note that your `call_endpoint` "
#     217         "might have a different name)."
#     218     )
#
# ValueError: File format not supported: filepath=/mnt/c/modelFiles/10splitsFlatten/tflite_NoQuant_Attention_SP_model.tflite. Keras 3 only supports V3 `.keras` files and legacy H5 format files (`.h5` extension). Note that the legacy SavedModel format is not supported by `load_model()` in Keras 3. In order to reload a TensorFlow SavedModel as an inference-only layer in Keras 3, use `keras.layers.TFSMLayer(/mnt/c/modelFiles/10splitsFlatten/tflite_NoQuant_Attention_SP_model.tflite, call_endpoint='serving_default')` (note that your `call_endpoint` might have a different name).

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Load both models
original_model = tf.keras.models.load_model("/mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_kfold_model_4.keras")
quantized_model = tf.keras.models.load_model("/mnt/c/modelFiles/10splitsFlatten/greyColor_quantized_kfold_model_0.keras", custom_objects=custom_objects)

# Build models if they aren't already
sample_input_shape = (None, 256, 256, 1)
original_model.build(input_shape=sample_input_shape)
quantized_model.build(input_shape=sample_input_shape)

# Extract weights for all convolutional layers
def get_all_conv_weights(model):
    weights = []
    for layer in model.layers:
        if isinstance(layer, (tf.keras.layers.Dense, QuantizedDense)):
            w = layer.get_weights()
            if w:
                weights.append(w[0])  # Only use kernel weights
    return weights

orig_weights_list = get_all_conv_weights(original_model)
quant_weights_list = get_all_conv_weights(quantized_model)

# Sanity check
num_layers = min(len(orig_weights_list), len(quant_weights_list))
print(f"Comparing {num_layers} Dense layers")

# Plot distributions for each layer
for i in range(num_layers):
    orig_weights = orig_weights_list[i].flatten()
    quant_weights = quant_weights_list[i].flatten()
    
    plt.figure(figsize=(15, 4))
    
    plt.subplot(1, 3, 1)
    plt.hist(orig_weights, bins=50, alpha=0.6, label='Original')
    plt.title(f'Layer {i+1} Original Weights')
    plt.xlabel('Weight Value')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 2)
    plt.hist(quant_weights, bins=50, alpha=0.6, label='Quantized', color='orange')
    plt.title(f'Layer {i+1} Quantized Weights')
    plt.xlabel('Weight Value')
    plt.ylabel('Frequency')
    
    plt.subplot(1, 3, 3)
    plt.hist(orig_weights, bins=50, alpha=0.5, label='Original')
    plt.hist(quant_weights, bins=50, alpha=0.5, label='Quantized')
    plt.title(f'Layer {i+1} Overlaid Distribution')
    plt.xlabel('Weight Value')
    plt.ylabel('Frequency')
    plt.legend()
    
    plt.tight_layout()
    plt.savefig(f'dense_layer_{i+1}_weight_distribution_comparison.png')
    plt.show()
# Out:
# Comparing 3 Dense layers

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# Supported layer types for activation visualization
ACTIVATION_LAYERS = (tf.keras.layers.Conv2D, tf.keras.layers.Dense, QuantizedConv2D, QuantizedDense)

def create_activation_models(model):
    input_shape = (256, 256, 1)
    input_layer = tf.keras.layers.Input(shape=input_shape)
    
    outputs = []
    layer_names = []
    x = input_layer

    for layer in model.layers:
        try:
            x = layer(x)
            if isinstance(layer, ACTIVATION_LAYERS):
                outputs.append(x)
                layer_names.append(layer.name)
        except:
            continue
    
    activation_model = tf.keras.Model(inputs=input_layer, outputs=outputs)
    return activation_model, layer_names

# Create activation models
orig_activation_model, orig_layer_names = create_activation_models(original_model)
quant_activation_model, quant_layer_names = create_activation_models(quantized_model)

# Ensure layer alignment
num_layers = min(len(orig_layer_names), len(quant_layer_names))

# Get a batch of input
x_batch, _ = next(iter(test_generator))

# Predict activations
orig_activations = orig_activation_model.predict(x_batch)
quant_activations = quant_activation_model.predict(x_batch)

# Plot activation distributions for each layer
for i in range(num_layers):
    orig_act = orig_activations[i].flatten()
    quant_act = quant_activations[i].flatten()

    plt.figure(figsize=(15, 4))

    plt.subplot(1, 3, 1)
    plt.hist(orig_act, bins=50, alpha=0.6, label='Original')
    plt.title(f'Layer {orig_layer_names[i]} Original')
    plt.xlabel('Activation Value')
    plt.ylabel('Frequency')

    plt.subplot(1, 3, 2)
    plt.hist(quant_act, bins=50, alpha=0.6, label='Quantized', color='orange')
    plt.title(f'Layer {quant_layer_names[i]} Quantized')
    plt.xlabel('Activation Value')
    plt.ylabel('Frequency')

    plt.subplot(1, 3, 3)
    plt.hist(orig_act, bins=50, alpha=0.5, label='Original')
    plt.hist(quant_act, bins=50, alpha=0.5, label='Quantized')
    plt.title(f'Layer {orig_layer_names[i]} Overlaid')
    plt.xlabel('Activation Value')
    plt.ylabel('Frequency')
    plt.legend()

    plt.tight_layout()
    plt.savefig(f'activation_distribution_layer_{i+1}_{orig_layer_names[i]}.png')
    plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# WARNING:tensorflow:5 out of the last 63 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ff4eb9d62a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 63 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7ff4eb9d62a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 570ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from collections import defaultdict

original_model = tf.keras.models.load_model("/mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_kfold_model_4.keras")
quantized_model = tf.keras.models.load_model("/mnt/c/modelFiles/10splitsFlatten/greyColor_quantized_kfold_model_0.keras", custom_objects=custom_objects)

# 1. Collect one image per class (assumes one-hot encoded labels)
def collect_one_sample_per_class(test_generator, num_classes=5):
    class_samples = {}
    for x_batch, y_batch in test_generator:
        for img, label in zip(x_batch, y_batch):
            class_idx = np.argmax(label)
            if class_idx not in class_samples:
                class_samples[class_idx] = img[np.newaxis, ...]  # Add batch dimension
            if len(class_samples) == num_classes:
                return class_samples
    return class_samples

# 2. Function to get intermediate layer outputs
def get_layer_outputs(model, input_data, num_layers=4):
    model.build(input_shape=(None, 256, 256, 1))
    outputs = []
    count = 0
    for layer in model.layers:
        if isinstance(layer, (tf.keras.layers.Conv2D, QuantizedConv2D)):
            temp_model = tf.keras.Model(inputs=model.inputs, outputs=layer.output)
            out = temp_model.predict(input_data)
            outputs.append(out)
            count += 1
            if count >= num_layers:
                break
    return outputs

# 3. Main logic
samples_per_class = collect_one_sample_per_class(test_generator, num_classes=5)

for class_idx, sample_img in samples_per_class.items():
    orig_features = get_layer_outputs(original_model, sample_img)
    quant_features = get_layer_outputs(quantized_model, sample_img)

    for layer_idx in range(min(len(orig_features), len(quant_features))):
        orig_feature = orig_features[layer_idx][0]   # Shape: (H, W, C)
        quant_feature = quant_features[layer_idx][0]

        # Compute average activation per channel
        orig_channel_strength = np.mean(orig_feature, axis=(0, 1))  # Shape: (C,)
        quant_channel_strength = np.mean(quant_feature, axis=(0, 1))  # Shape: (C,)

        # Get indices of top 8 channels
        top8_orig_indices = np.argsort(orig_channel_strength)[-8:][::-1]
        top8_quant_indices = np.argsort(quant_channel_strength)[-8:][::-1]

        plt.figure(figsize=(16, 8))
        plt.suptitle(f'Layer {layer_idx+1} Top-Activated Feature Maps', fontsize=16)

        for idx, (orig_ch, quant_ch) in enumerate(zip(top8_orig_indices, top8_quant_indices)):
            # Original model top channel
            plt.subplot(2, 8, idx + 1)
            plt.imshow(orig_feature[:, :, orig_ch], cmap='viridis')
            plt.title(f'Orig Ch {orig_ch}')
            plt.axis('off')

            # Quantized model top channel
            plt.subplot(2, 8, idx + 9)
            plt.imshow(quant_feature[:, :, quant_ch], cmap='viridis')
            plt.title(f'Quant Ch {quant_ch}')
            plt.axis('off')

        plt.tight_layout(rect=[0, 0, 1, 0.95])
        plt.savefig(f'top_feature_map_layer_{layer_idx+1}_{class_idx+1}.png')
        plt.show()

# %%
def visualize_quantization_effects(original_model_path, quantized_model_path, test_generator):
    """
    Visualize the effects of quantization on model weights and activations.
    
    Args:
        original_model_path: Path to the original (non-quantized) model
        quantized_model_path: Path to the quantized-aware trained model
        test_generator: A data generator providing test data
    """
    import matplotlib.pyplot as plt
    import numpy as np
    import tensorflow as tf
    
    # Define custom objects for loading the quantized model
    custom_objects = {'QuantizedConv2D': QuantizedConv2D, 'QuantizedDense': QuantizedDense}
    
    # Load both models
    original_model = tf.keras.models.load_model(original_model_path)
    quantized_model = tf.keras.models.load_model(quantized_model_path, custom_objects=custom_objects)
    # Build models if they aren't already
    sample_input_shape = (None, 256, 256, 1)
    original_model.build(input_shape=sample_input_shape)
    quantized_model.build(input_shape=sample_input_shape)
    x_batch, _ = next(iter(test_generator))
    # Calculate size reduction
    def get_model_size(model):
        """Get approximate model size in MB"""
        weights = [w.numpy() for w in model.weights]
        total_params = sum(w.size for w in weights)
        
        # Calculate size in MB (32-bit float = 4 bytes)
        size_mb = (total_params * 4) / (1024 * 1024)
        return size_mb
    
    orig_size = get_model_size(original_model)
    
    # Simulate quantized model size (8-bit = 1 byte)
    quant_size = get_model_size(quantized_model) / 4  # Approximation: 8-bit is 1/4 of 32-bit
    
    print(f"Original model size: {orig_size:.2f} MB")
    print(f"Quantized model size: {quant_size:.2f} MB")
    print(f"Size reduction: {(1 - quant_size/orig_size) * 100:.1f}%")
    
    # Measure and compare inference speed
    import time
    
    # Warm up
    _ = original_model.predict(x_batch[:10])
    _ = quantized_model.predict(x_batch[:10])
    
    # Measure original model speed
    start_time = time.time()
    _ = original_model.predict(x_batch)
    orig_time = time.time() - start_time
    
    # Measure quantized model speed
    start_time = time.time()
    _ = quantized_model.predict(x_batch)
    quant_time = time.time() - start_time
    
    print(f"Original model inference time: {orig_time:.4f} seconds")
    print(f"Quantized model inference time: {quant_time:.4f} seconds")
    print(f"Speed improvement: {(1 - quant_time/orig_time) * 100:.1f}%")
    
    # Return summary as dictionary for further analysis
    return {
        "original_size_mb": orig_size,
        "quantized_size_mb": quant_size,
        "size_reduction_percent": (1 - quant_size/orig_size) * 100,
        "original_inference_time": orig_time,
        "quantized_inference_time": quant_time,
        "speed_improvement_percent": (1 - quant_time/orig_time) * 100
    }

visualize_quantization_effects("/mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_kfold_model_4.keras", "/mnt/c/modelFiles/10splitsFlatten/greyColor_quantized_kfold_model_0.keras", test_generator)

# %% [markdown]
# **CLASS BASED ADAPTIVE ACCURACY THRESHOLDING**

# %%
#PER CLASS THRESHOLDING
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import confusion_matrix, f1_score, classification_report, roc_curve, auc
import tensorflow as tf

def calculate_metrics_multiclass(y_true, y_pred_probs, thresholds):
    """
    Apply per-class thresholds and compute evaluation metrics.
    
    Args:
        y_true: True class labels
        y_pred_probs: Predicted probabilities for each class
        thresholds: List of per-class thresholds
    
    Returns:
        y_pred: Final predicted labels based on adaptive thresholds
        cm: Confusion matrix
        f1_scores: Per-class F1 scores
    """
    num_samples, num_classes = y_pred_probs.shape
    y_pred = np.full(y_true.shape, -1)

    for idx in range(num_samples):
        valid_classes = []
        for i in range(num_classes):
            if y_pred_probs[idx, i] >= thresholds[i]:
                valid_classes.append(i)

        if valid_classes:
            # Among the valid classes, choose the one with the highest probability
            best_class = max(valid_classes, key=lambda i: y_pred_probs[idx, i])
            y_pred[idx] = best_class
        else:
            # Fallback to argmax if no class exceeds its threshold
            y_pred[idx] = np.argmax(y_pred_probs[idx])

    cm = confusion_matrix(y_true, y_pred)
    f1_scores = f1_score(y_true, y_pred, average=None)
    overall_f1 = f1_score(y_true, y_pred, average="macro")

    return y_pred, cm, f1_scores, overall_f1


def adaptive_threshold_determination_multiclass2(model, test_generator, threshold_range=None):
    """
    Determine adaptive per-class thresholds and evaluate the model.
    
    Args:
        model: Trained model
        test_generator: Test data generator
        threshold_range: Range of thresholds to test (default: 0 to 1 in 0.01 steps)
    
    Returns:
        optimal_thresholds: List of per-class optimal thresholds
    """
    # Reset generator and get predictions
    test_generator.reset()
    steps = len(test_generator)
    
    y_true = []
    y_pred_probs = []
    
    for _ in range(steps):
        x_batch, y_batch = next(test_generator)
        batch_pred = model.predict(x_batch, verbose=0)
        y_true.extend(np.argmax(y_batch, axis=1))  # Convert one-hot labels to indices
        y_pred_probs.extend(batch_pred)  # Store full probability distribution
    
    y_true = np.array(y_true)
    y_pred_probs = np.array(y_pred_probs)
    
    num_classes = y_pred_probs.shape[1]
    class_names = list(test_generator.class_indices.keys())

    # Set threshold search range
    if threshold_range is None:
        threshold_range = np.arange(0, 1.01, 0.01)

    # Find best threshold for each class based on F1-score
    best_thresholds = []
    best_f1_scores = []

    for i in range(num_classes):
        best_threshold = 0.5  # Default
        best_f1 = 0.0

        for threshold in threshold_range:
            temp_thresholds = [0.5] * num_classes  # Start with default 0.5 for all
            temp_thresholds[i] = threshold  # Vary only the current class
            
            _, _, f1_scores, _ = calculate_metrics_multiclass(y_true, y_pred_probs, temp_thresholds)
            if f1_scores[i] > best_f1:
                best_f1 = f1_scores[i]
                best_threshold = threshold

        best_thresholds.append(best_threshold)
        best_f1_scores.append(best_f1)

    # Apply optimal thresholds
    y_pred, cm, f1_scores, overall_f1 = calculate_metrics_multiclass(y_true, y_pred_probs, best_thresholds)

    # Compute ROC Curve & AUC per class
    fpr = {}
    tpr = {}
    roc_auc = {}

    for i in range(num_classes):
        y_true_binary = (y_true == i).astype(int)
        y_pred_binary = y_pred_probs[:, i]

        fpr[i], tpr[i], _ = roc_curve(y_true_binary, y_pred_binary)
        roc_auc[i] = auc(fpr[i], tpr[i])

    macro_auc = np.mean(list(roc_auc.values()))

    # Plot confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

    # Plot ROC Curves
    plt.figure(figsize=(8, 6))
    for i in range(num_classes):
        plt.plot(fpr[i], tpr[i], label=f'Class {class_names[i]} (AUC = {roc_auc[i]:.2f})')
    
    plt.plot([0, 1], [0, 1], 'k--')  # Random classifier line
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Multiclass ROC Curve (Macro AUC = {macro_auc:.2f})')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Print classification report
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))

    # Print optimal thresholds
    print("\nOptimal Per-Class Thresholds:")
    for i, class_name in enumerate(class_names):
        print(f"{class_name}: {best_thresholds[i]:.2f} (F1 = {best_f1_scores[i]:.4f})")

    print(f"\nOverall Macro F1 Score: {overall_f1:.4f}")
    print(f"Macro-Averaged ROC AUC: {macro_auc:.4f}")

    return best_thresholds


# Usage:
def evaluate_multiclass_with_adaptive_threshold(model, test_generator):
    """
    Evaluate model on a multi-class dataset using adaptive thresholding.
    """
    optimal_thresholds = adaptive_threshold_determination_multiclass2(model, test_generator)
    return optimal_thresholds

cnn = tf.keras.models.load_model("/mnt/c/modelFiles/10splitsFlatten/greyColor_quantized_kfold_model_0.keras")
try:
    evaluate_multiclass_with_adaptive_threshold(cnn,test_generator)
except StopIteration as e:
    print("iteration stopped. evaluating again.")
    evaluate_multiclass_with_adaptive_threshold(cnn,test_generator)
# Out:
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       1.00      1.00      1.00       350
# horizontal_line       0.95      0.96      0.96       171
#           stain       0.99      0.99      0.99       158
#            tear       0.99      0.99      0.99       347
#   vertical_line       0.99      0.96      0.98       169
#
#        accuracy                           0.98      1195
#       macro avg       0.98      0.98      0.98      1195
#    weighted avg       0.99      0.98      0.98      1195
#
#
# Optimal Per-Class Thresholds:
# No_Defect: 0.31 (F1 = 1.0000)
# horizontal_line: 0.37 (F1 = 0.9538)
# stain: 0.19 (F1 = 0.9905)
# tear: 0.26 (F1 = 0.9856)
# vertical_line: 0.35 (F1 = 0.9760)
#
# Overall Macro F1 Score: 0.9817
# Macro-Averaged ROC AUC: 0.9991

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.metrics import confusion_matrix, f1_score, classification_report, roc_curve, auc
import tensorflow as tf

def run_tflite_inference(interpreter, input_data):
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    # Quantization parameters for input
    input_index = input_details[0]['index']
    input_dtype = input_details[0]['dtype']
    input_scale, input_zero_point = input_details[0]['quantization']

    # Quantize input if needed
    if input_dtype == np.int8:
        input_data = input_data / input_scale + input_zero_point
        input_data = np.clip(np.round(input_data), -128, 127).astype(np.int8)
    elif input_dtype == np.uint8:
        input_data = input_data / input_scale + input_zero_point
        input_data = np.clip(np.round(input_data), 0, 255).astype(np.uint8)
    else:
        input_data = input_data.astype(input_dtype)

    interpreter.set_tensor(input_index, input_data)
    interpreter.invoke()

    # Dequantize output 
    output_index = output_details[0]['index']
    output_data = interpreter.get_tensor(output_index)

    output_dtype = output_details[0]['dtype']
    output_scale, output_zero_point = output_details[0]['quantization']

    if output_dtype == np.int8:
        output_data = (output_data.astype(np.float32) - output_zero_point) * output_scale
    elif output_dtype == np.uint8:
        output_data = (output_data.astype(np.float32) - output_zero_point) * output_scale

    return output_data

import numpy as np
from sklearn.metrics import confusion_matrix, f1_score

def calculate_metrics_multiclass(y_true, y_pred_probs, thresholds):
    num_samples, num_classes = y_pred_probs.shape
    y_pred = np.full(y_true.shape, -1)

    for idx in range(num_samples):
        valid_classes = []
        for i in range(num_classes):
            if y_pred_probs[idx, i] >= thresholds[i]:
                valid_classes.append(i)

        if valid_classes:
            # Among the valid classes, choose the one with the highest probability
            best_class = max(valid_classes, key=lambda i: y_pred_probs[idx, i])
            y_pred[idx] = best_class
        else:
            # Fallback to argmax if no class exceeds its threshold
            y_pred[idx] = np.argmax(y_pred_probs[idx])

    cm = confusion_matrix(y_true, y_pred)
    f1_scores = f1_score(y_true, y_pred, average=None)
    overall_f1 = f1_score(y_true, y_pred, average="macro")

    return y_pred, cm, f1_scores, overall_f1

def adaptive_threshold_determination_multiclass2_tflite(tflite_model_path, test_generator, threshold_range=None):
    interpreter = tf.lite.Interpreter(model_path=tflite_model_path)
    interpreter.allocate_tensors()

    steps = len(test_generator)
    y_true = []
    y_pred_probs = []

    for _ in range(steps):
        x_batch, y_batch = next(test_generator)
        batch_pred = []

        for i in range(x_batch.shape[0]):
            input_tensor = np.expand_dims(x_batch[i], axis=0).astype(np.float32)
            output = run_tflite_inference(interpreter, input_tensor)
            batch_pred.append(output[0])  

        y_true.extend(np.argmax(y_batch, axis=1))
        y_pred_probs.extend(batch_pred)

    y_true = np.array(y_true)
    y_pred_probs = np.array(y_pred_probs)

    num_classes = y_pred_probs.shape[1]
    class_names = list(test_generator.class_indices.keys())

    if threshold_range is None:
        threshold_range = np.arange(0, 1.01, 0.01)

    best_thresholds = []
    best_f1_scores = []

    for i in range(num_classes):
        best_threshold = 0.5
        best_f1 = 0.0

        for threshold in threshold_range:
            temp_thresholds = [0.5] * num_classes
            temp_thresholds[i] = threshold

            _, _, f1_scores, _ = calculate_metrics_multiclass(y_true, y_pred_probs, temp_thresholds)
            if f1_scores[i] > best_f1:
                best_f1 = f1_scores[i]
                best_threshold = threshold

        best_thresholds.append(best_threshold)
        best_f1_scores.append(best_f1)

    y_pred, cm, f1_scores, overall_f1 = calculate_metrics_multiclass(y_true, y_pred_probs, best_thresholds)

    fpr = {}
    tpr = {}
    roc_auc = {}

    for i in range(num_classes):
        y_true_binary = (y_true == i).astype(int)
        y_pred_binary = y_pred_probs[:, i]

        fpr[i], tpr[i], _ = roc_curve(y_true_binary, y_pred_binary)
        roc_auc[i] = auc(fpr[i], tpr[i])

    macro_auc = np.mean(list(roc_auc.values()))

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

    plt.figure(figsize=(8, 6))
    for i in range(num_classes):
        plt.plot(fpr[i], tpr[i], label=f'Class {class_names[i]} (AUC = {roc_auc[i]:.2f})')
    
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'Multiclass ROC Curve (Macro AUC = {macro_auc:.2f})')
    plt.legend()
    plt.grid(True)
    plt.show()

    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, target_names=class_names))

    print("\nOptimal Per-Class Thresholds:")
    for i, class_name in enumerate(class_names):
        print(f"{class_name}: {best_thresholds[i]:.2f} (F1 = {best_f1_scores[i]:.4f})")

    print(f"\nOverall Macro F1 Score: {overall_f1:.4f}")
    print(f"Macro-Averaged ROC AUC: {macro_auc:.4f}")

    return best_thresholds

def evaluate_multiclass_with_adaptive_threshold_tflite(tflite_model_path, test_generator):
    optimal_thresholds = adaptive_threshold_determination_multiclass2_tflite(tflite_model_path, test_generator)
    return optimal_thresholds

# %%
try:
    optimal_thresholds = evaluate_multiclass_with_adaptive_threshold_tflite("/mnt/c/modelFiles/10splitsFlatten/quantized_kfold_model_0.tflite" , test_generator)
except StopIteration as e:
    print("iteration stopped. evaluating again.")
    optimal_thresholds = evaluate_multiclass_with_adaptive_threshold_tflite("/mnt/c/modelFiles/10splitsFlatten/quantized_kfold_model_0.tflite" , test_generator)
# Out:
# iteration stopped. evaluating again.
# Classification Report:
#                  precision    recall  f1-score   support
#
#       No_Defect       0.99      1.00      0.99       350
# horizontal_line       0.91      0.95      0.93       171
#           stain       0.99      0.98      0.98       158
#            tear       0.99      0.97      0.98       347
#   vertical_line       0.96      0.94      0.95       169
#
#        accuracy                           0.97      1195
#       macro avg       0.97      0.97      0.97      1195
#    weighted avg       0.97      0.97      0.97      1195
#
#
# Optimal Per-Class Thresholds:
# No_Defect: 0.51 (F1 = 0.9957)
# horizontal_line: 0.50 (F1 = 0.9278)
# stain: 0.25 (F1 = 0.9841)
# tear: 0.48 (F1 = 0.9754)
# vertical_line: 0.34 (F1 = 0.9493)
#
# Overall Macro F1 Score: 0.9672
# Macro-Averaged ROC AUC: 0.9975

# %% [markdown]
# ***QAT GENERIC KERAS MODEL RESOURCE UTILISATIONS AND INFERENCE***

# %%
import time
import psutil
import GPUtil
import pynvml
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
from tensorflow.compat.v1.profiler import profile
from tensorflow.compat.v1.profiler import ProfileOptionBuilder
import keras

#best model
model=keras.models.load_model("/mnt/c/modelFiles/10splitsFlatten/greyColor_quantized_kfold_model_0.keras")

# Load a single test image
img_path = "/mnt/c/newTrain/Train/line/17.jpg"
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
img = cv2.resize(img, (256, 256))
img = img.astype(np.float32) / 255.0

# Stack into 1 channel
stacked = np.stack([img], axis=-1)  # shape: (256, 256, 1)
img_array = np.expand_dims(stacked, axis=0)  # shape: (1, 256, 256, 1)

# Cold start timing
t1 = time.time()
ensemble_probs = model.predict(img_array, verbose=0)
t2 = time.time()
cold_start_time = t2 - t1

# Inference timing
num_trials = 10
times = []
for _ in range(num_trials):
    t1 = time.time()
    _ = model.predict(img_array, verbose=0)
    t2 = time.time()
    times.append(t2 - t1)
inference_time = np.mean(times)

def get_model_size(model):
        """Get approximate model size in MB"""
        weights = [w.numpy() for w in model.weights]
        total_params = sum(w.size for w in weights)
        
        # Calculate size in MB (32-bit float = 4 bytes)
        size_mb = (total_params * 4) / (1024 * 1024)
        return size_mb
# model size
model_size = get_model_size(model)

# Memory usage
process = psutil.Process(os.getpid())
mem_before = process.memory_info().rss / (1024 * 1024)
_ = np.mean([model.predict(img_array, verbose=0)], axis=0)
mem_after = process.memory_info().rss / (1024 * 1024)
memory_usage = mem_after - mem_before

# GPU and CPU stats
gpus = GPUtil.getGPUs()
gpu_usage = gpus[0].load * 100 if gpus else None
cpu_util = psutil.cpu_percent(interval=1)

# Power usage (CPU only)
try:
    power_usage = psutil.sensors_battery().power_plugged
except AttributeError:
    power_usage = None

# GPU power usage
def get_gpu_power():
    pynvml.nvmlInit()
    handle = pynvml.nvmlDeviceGetHandleByIndex(0)
    power = pynvml.nvmlDeviceGetPowerUsage(handle) / 1000
    pynvml.nvmlShutdown()
    return power
power_watts = get_gpu_power()

# FLOPs
import io
from contextlib import redirect_stdout

def get_flops(model, input_shape):
    concrete = tf.function(lambda inputs: model(inputs)).get_concrete_function(
        tf.TensorSpec([1] + list(input_shape), model.inputs[0].dtype)
    )
    frozen_func = convert_variables_to_constants_v2(concrete)
    graph = frozen_func.graph

    run_meta = tf.compat.v1.RunMetadata()
    opts = ProfileOptionBuilder.float_operation()

    # Suppress stdout
    with io.StringIO() as buf, redirect_stdout(buf):
        flops = profile(graph, run_meta=run_meta, options=opts)
    
    return flops.total_float_ops

input_shape = (256, 256, 1)
flops = get_flops(models[0], input_shape) * len(models)  # total ensemble FLOPs

# Parameter count
num_params = model.count_params()

# Data load timing
t1 = time.time()
_ = tf.keras.preprocessing.image.load_img(img_path, target_size=(256, 256))
t2 = time.time()
data_loading_time = t2 - t1

# Sparsity
def get_sparsity_ratio(model):
    total_params = np.sum([np.prod(w.shape) for w in model.weights])
    zero_params = np.sum([np.sum(w.numpy() == 0) for w in model.weights])
    return zero_params / total_params

avg_sparsity= get_sparsity_ratio(model)


# Energy efficiency
def get_energy_efficiency(flops, power_watts=None):
    if power_watts is None:
        return "Power consumption data missing"
    return flops / power_watts

energy_efficiency = get_energy_efficiency(flops, power_watts)

# results
print(f"Cold Start Time: {cold_start_time:.4f} seconds")
print(f"Average Inference Time: {inference_time:.4f} seconds")
print(f"Model Size: {model_size:.2f} MB")
print(f"Memory Usage: {memory_usage:.2f} MB")
print(f"Total FLOPs (Ensemble): {flops}")
print(f"Total Parameters (Ensemble): {num_params}")
print(f"GPU Utilization: {gpu_usage:.2f}%" if gpu_usage is not None else "GPU Utilization: Not Available")
print(f"CPU Utilization: {cpu_util:.2f}%")
print(f"Power Consumption (CPU): {power_usage}")
print(f"Power Watts (GPU): {power_watts}")
print(f"Data Loading Time: {data_loading_time:.4f} seconds")
print(f"Sparsity Ratio: {avg_sparsity:.4f}")
print(f"Energy Efficiency (FLOPs/Watt): {energy_efficiency}")
# Out:
# I0000 00:00:1746783160.678142  261896 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1746783160.678308  261896 single_machine.cc:361] Starting new session
# I0000 00:00:1746783160.678868  261896 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1767 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# Profile:
# node name | # float_ops
# _TFProfRoot (--/65.34m flops)
#   functional_1_1/quantized_conv2d_4_1/Conv2D (18.87m/18.87m flops)
#   functional_1_1/quantized_conv2d_5_1/Conv2D (16.26m/16.26m flops)
#   functional_1_1/quantized_conv2d_6_1/Conv2D (7.23m/7.23m flops)
#   functional_1_1/quantized_conv2d_7_1/Conv2D (5.42m/5.42m flops)
#   functional_1_1/quantized_conv2d_4_1/clip_by_value_1 (1.05m/2.10m flops)
#     functional_1_1/quantized_conv2d_4_1/clip_by_value_1/Minimum (1.05m/1.05m flops)
#   functional_1_1/quantized_conv2d_4_1/BiasAdd (1.05m/1.05m flops)
#   functional_1_1/quantized_conv2d_4_1/add_4 (1.05m/1.05m flops)
#   functional_1_1/quantized_conv2d_4_1/add_5 (1.05m/1.05m flops)
#   functional_1_1/quantized_conv2d_4_1/mul_1 (1.05m/1.05m flops)
#   functional_1_1/quantized_conv2d_4_1/sub_4 (1.05m/1.05m flops)
#   functional_1_1/quantized_conv2d_4_1/sub_5 (1.05m/1.05m flops)
#   functional_1_1/quantized_conv2d_4_1/truediv_3 (1.05m/1.05m flops)
#   functional_1_1/max_pooling2d_4_1/MaxPool2d (1.02m/1.02m flops)
#   functional_1_1/quantized_dense_2_1/MatMul (884.74k/884.74k flops)
#   functional_1_1/quantized_dense_2_1/clip_by_value (442.37k/884.74k flops)
#     functional_1_1/quantized_dense_2_1/clip_by_value/Minimum (442.37k/442.37k flops)
#   functional_1_1/quantized_dense_2_1/Add_2 (442.37k/442.37k flops)
#   functional_1_1/quantized_dense_2_1/Sub_1 (442.37k/442.37k flops)
#   functional_1_1/quantized_dense_2_1/add_1 (442.37k/442.37k flops)
#   functional_1_1/quantized_dense_2_1/mul (442.37k/442.37k flops)
#   functional_1_1/quantized_dense_2_1/sub_2 (442.37k/442.37k flops)
#   functional_1_1/quantized_dense_2_1/truediv_1 (442.37k/442.37k flops)
#   functional_1_1/quantized_dense_3_1/MatMul (262.14k/262.14k flops)
#   functional_1_1/quantized_dense_3_1/clip_by_value (131.07k/262.14k flops)
#     functional_1_1/quantized_dense_3_1/clip_by_value/Minimum (131.07k/131.07k flops)
#   functional_1_1/quantized_dense_3_1/Add_2 (131.07k/131.07k flops)
#   functional_1_1/quantized_dense_3_1/Sub_1 (131.07k/131.07k flops)
#   functional_1_1/quantized_dense_3_1/add_1 (131.07k/131.07k flops)
#   functional_1_1/quantized_dense_3_1/mul (131.07k/131.07k flops)
#   functional_1_1/quantized_dense_3_1/sub_2 (131.07k/131.07k flops)
#   functional_1_1/quantized_dense_3_1/truediv_1 (131.07k/131.07k flops)
#   functional_1_1/quantized_conv2d_5_1/clip_by_value_1 (56.45k/112.90k flops)
#     functional_1_1/quantized_conv2d_5_1/clip_by_value_1/Minimum (56.45k/56.45k flops)
#   functional_1_1/quantized_conv2d_7_1/clip_by_value (55.30k/110.59k flops)
#     functional_1_1/quantized_conv2d_7_1/clip_by_value/Minimum (55.30k/55.30k flops)
#   functional_1_1/max_pooling2d_5_1/MaxPool2d (56.45k/56.45k flops)
#   functional_1_1/quantized_conv2d_5_1/BiasAdd (56.45k/56.45k flops)
#   functional_1_1/quantized_conv2d_5_1/add_4 (56.45k/56.45k flops)
#   functional_1_1/quantized_conv2d_5_1/add_5 (56.45k/56.45k flops)
#   functional_1_1/quantized_conv2d_5_1/mul_1 (56.45k/56.45k flops)
#   functional_1_1/quantized_conv2d_5_1/sub_4 (56.45k/56.45k flops)
#   functional_1_1/quantized_conv2d_5_1/sub_5 (56.45k/56.45k flops)
#   functional_1_1/quantized_conv2d_5_1/truediv_3 (56.45k/56.45k flops)
#   functional_1_1/quantized_conv2d_7_1/Add_2 (55.30k/55.30k flops)
#   functional_1_1/quantized_conv2d_7_1/Sub_1 (55.30k/55.30k flops)
#   functional_1_1/quantized_conv2d_7_1/add_1 (55.30k/55.30k flops)
#   functional_1_1/quantized_conv2d_7_1/mul (55.30k/55.30k flops)
#   functional_1_1/quantized_conv2d_7_1/sub_2 (55.30k/55.30k flops)
#   functional_1_1/quantized_conv2d_7_1/truediv_1 (55.30k/55.30k flops)
#   functional_1_1/quantized_conv2d_6_1/clip_by_value (18.43k/36.86k flops)
#     functional_1_1/quantized_conv2d_6_1/clip_by_value/Minimum (18.43k/18.43k flops)
#   functional_1_1/quantized_conv2d_6_1/clip_by_value_1 (12.54k/25.09k flops)
#     functional_1_1/quantized_conv2d_6_1/clip_by_value_1/Minimum (12.54k/12.54k flops)
#   functional_1_1/quantized_conv2d_6_1/Add_2 (18.43k/18.43k flops)
#   functional_1_1/quantized_conv2d_6_1/Sub_1 (18.43k/18.43k flops)
#   functional_1_1/quantized_conv2d_6_1/add_1 (18.43k/18.43k flops)
#   functional_1_1/quantized_conv2d_6_1/mul (18.43k/18.43k flops)
#   functional_1_1/quantized_conv2d_6_1/sub_2 (18.43k/18.43k flops)
#   functional_1_1/quantized_conv2d_6_1/truediv_1 (18.43k/18.43k flops)
#   functional_1_1/max_pooling2d_6_1/MaxPool2d (12.54k/12.54k flops)
#   functional_1_1/quantized_conv2d_6_1/BiasAdd (12.54k/12.54k flops)
#   functional_1_1/quantized_conv2d_6_1/add_4 (12.54k/12.54k flops)
#   functional_1_1/quantized_conv2d_6_1/add_5 (12.54k/12.54k flops)
#   functional_1_1/quantized_conv2d_6_1/mul_1 (12.54k/12.54k flops)
#   functional_1_1/quantized_conv2d_6_1/sub_4 (12.54k/12.54k flops)
#   functional_1_1/quantized_conv2d_6_1/sub_5 (12.54k/12.54k flops)
#   functional_1_1/quantized_conv2d_6_1/truediv_3 (12.54k/12.54k flops)
#   functional_1_1/quantized_conv2d_7_1/clip_by_value_1 (4.70k/9.41k flops)
#     functional_1_1/quantized_conv2d_7_1/clip_by_value_1/Minimum (4.70k/4.70k flops)
#   functional_1_1/quantized_conv2d_5_1/clip_by_value (4.61k/9.22k flops)
#     functional_1_1/quantized_conv2d_5_1/clip_by_value/Minimum (4.61k/4.61k flops)
#   functional_1_1/quantized_conv2d_7_1/BiasAdd (4.70k/4.70k flops)
#   functional_1_1/quantized_conv2d_7_1/add_4 (4.70k/4.70k flops)
#   functional_1_1/quantized_conv2d_7_1/add_5 (4.70k/4.70k flops)
#   functional_1_1/quantized_conv2d_7_1/mul_1 (4.70k/4.70k flops)
#   functional_1_1/quantized_conv2d_7_1/sub_4 (4.70k/4.70k flops)
#   functional_1_1/quantized_conv2d_7_1/sub_5 (4.70k/4.70k flops)
#   functional_1_1/quantized_conv2d_7_1/truediv_3 (4.70k/4.70k flops)
#   functional_1_1/quantized_conv2d_5_1/Add_2 (4.61k/4.61k flops)
#   functional_1_1/quantized_conv2d_5_1/Sub_1 (4.61k/4.61k flops)
#   functional_1_1/quantized_conv2d_5_1/add_1 (4.61k/4.61k flops)
#   functional_1_1/quantized_conv2d_5_1/mul (4.61k/4.61k flops)
#   functional_1_1/quantized_conv2d_5_1/sub_2 (4.61k/4.61k flops)
#   functional_1_1/quantized_conv2d_5_1/truediv_1 (4.61k/4.61k flops)
#   functional_1_1/max_pooling2d_7_1/MaxPool2d (3.46k/3.46k flops)
#   functional_1_1/dense_1_1/MatMul (2.56k/2.56k flops)
#   functional_1_1/quantized_dense_2_1/clip_by_value_1 (512/1.02k flops)
#     functional_1_1/quantized_dense_2_1/clip_by_value_1/Minimum (512/512 flops)
#   functional_1_1/quantized_dense_2_1/BiasAdd (512/512 flops)
#   functional_1_1/quantized_dense_2_1/add_4 (512/512 flops)
#   functional_1_1/quantized_dense_2_1/add_5 (512/512 flops)
#   functional_1_1/quantized_dense_2_1/mul_1 (512/512 flops)
#   functional_1_1/quantized_dense_2_1/sub_4 (512/512 flops)
#   functional_1_1/quantized_dense_2_1/sub_5 (512/512 flops)
#   functional_1_1/quantized_dense_2_1/truediv_3 (512/512 flops)
#   functional_1_1/quantized_dense_3_1/clip_by_value_1 (256/512 flops)
#     functional_1_1/quantized_dense_3_1/clip_by_value_1/Minimum (256/256 flops)
#   functional_1_1/quantized_conv2d_4_1/clip_by_value (144/288 flops)
#     functional_1_1/quantized_conv2d_4_1/clip_by_value/Minimum (144/144 flops)
#   functional_1_1/quantized_dense_3_1/BiasAdd (256/256 flops)
#   functional_1_1/quantized_dense_3_1/add_4 (256/256 flops)
#   functional_1_1/quantized_dense_3_1/add_5 (256/256 flops)
#   functional_1_1/quantized_dense_3_1/mul_1 (256/256 flops)
#   functional_1_1/quantized_dense_3_1/sub_4 (256/256 flops)
#   functional_1_1/quantized_dense_3_1/sub_5 (256/256 flops)
#   functional_1_1/quantized_dense_3_1/truediv_3 (256/256 flops)
#   functional_1_1/quantized_conv2d_4_1/Add_2 (144/144 flops)
#   functional_1_1/quantized_conv2d_4_1/Sub_1 (144/144 flops)
#   functional_1_1/quantized_conv2d_4_1/add_1 (144/144 flops)
#   functional_1_1/quantized_conv2d_4_1/mul (144/144 flops)
#   functional_1_1/quantized_conv2d_4_1/sub_2 (144/144 flops)
#   functional_1_1/quantized_conv2d_4_1/truediv_1 (144/144 flops)
#   functional_1_1/dense_1_1/Softmax (25/25 flops)
#   functional_1_1/dense_1_1/BiasAdd (5/5 flops)
#   functional_1_1/quantized_conv2d_4_1/Add (1/1 flops)
#   functional_1_1/quantized_conv2d_4_1/Add_3 (1/1 flops)
#   functional_1_1/quantized_conv2d_4_1/Maximum (1/1 flops)
#   functional_1_1/quantized_conv2d_4_1/Maximum_1 (1/1 flops)
#   functional_1_1/quantized_conv2d_4_1/sub (1/1 flops)
#   functional_1_1/quantized_conv2d_4_1/sub_3 (1/1 flops)
#   functional_1_1/quantized_conv2d_4_1/truediv (1/1 flops)
#   functional_1_1/quantized_conv2d_4_1/truediv_2 (1/1 flops)
#   functional_1_1/quantized_conv2d_5_1/Add (1/1 flops)
#   functional_1_1/quantized_conv2d_5_1/Add_3 (1/1 flops)
#   functional_1_1/quantized_conv2d_5_1/Maximum (1/1 flops)
#   functional_1_1/quantized_conv2d_5_1/Maximum_1 (1/1 flops)
#   functional_1_1/quantized_conv2d_5_1/sub (1/1 flops)
#   functional_1_1/quantized_conv2d_5_1/sub_3 (1/1 flops)
#   functional_1_1/quantized_conv2d_5_1/truediv (1/1 flops)
#   functional_1_1/quantized_conv2d_5_1/truediv_2 (1/1 flops)
#   functional_1_1/quantized_conv2d_6_1/Add (1/1 flops)
#   functional_1_1/quantized_conv2d_6_1/Add_3 (1/1 flops)
#   functional_1_1/quantized_conv2d_6_1/Maximum (1/1 flops)
#   functional_1_1/quantized_conv2d_6_1/Maximum_1 (1/1 flops)
#   functional_1_1/quantized_conv2d_6_1/sub (1/1 flops)
#   functional_1_1/quantized_conv2d_6_1/sub_3 (1/1 flops)
#   functional_1_1/quantized_conv2d_6_1/truediv (1/1 flops)
#   functional_1_1/quantized_conv2d_6_1/truediv_2 (1/1 flops)
#   functional_1_1/quantized_conv2d_7_1/Add (1/1 flops)
#   functional_1_1/quantized_conv2d_7_1/Add_3 (1/1 flops)
#   functional_1_1/quantized_conv2d_7_1/Maximum (1/1 flops)
#   functional_1_1/quantized_conv2d_7_1/Maximum_1 (1/1 flops)
#   functional_1_1/quantized_conv2d_7_1/sub (1/1 flops)
#   functional_1_1/quantized_conv2d_7_1/sub_3 (1/1 flops)
#   functional_1_1/quantized_conv2d_7_1/truediv (1/1 flops)
#   functional_1_1/quantized_conv2d_7_1/truediv_2 (1/1 flops)
#   functional_1_1/quantized_dense_2_1/Add (1/1 flops)
#   functional_1_1/quantized_dense_2_1/Add_3 (1/1 flops)
#   functional_1_1/quantized_dense_2_1/Maximum (1/1 flops)
#   functional_1_1/quantized_dense_2_1/Maximum_1 (1/1 flops)
#   functional_1_1/quantized_dense_2_1/sub (1/1 flops)
#   functional_1_1/quantized_dense_2_1/sub_3 (1/1 flops)
#   functional_1_1/quantized_dense_2_1/truediv (1/1 flops)
#   functional_1_1/quantized_dense_2_1/truediv_2 (1/1 flops)
#   functional_1_1/quantized_dense_3_1/Add (1/1 flops)
#   functional_1_1/quantized_dense_3_1/Add_3 (1/1 flops)
#   functional_1_1/quantized_dense_3_1/Maximum (1/1 flops)
#   functional_1_1/quantized_dense_3_1/Maximum_1 (1/1 flops)
#   functional_1_1/quantized_dense_3_1/sub (1/1 flops)
#   functional_1_1/quantized_dense_3_1/sub_3 (1/1 flops)
#   functional_1_1/quantized_dense_3_1/truediv (1/1 flops)
#   functional_1_1/quantized_dense_3_1/truediv_2 (1/1 flops)
#
# ======================End of Report==========================
# Cold Start Time: 0.6012 seconds
# Average Inference Time: 0.0716 seconds
# Model Size: 2.50 MB
# Memory Usage: 0.14 MB
# Total FLOPs (Ensemble): 653364940
# Total Parameters (Ensemble): 654205
# GPU Utilization: 7.00%
# CPU Utilization: 0.30%
# Power Consumption (CPU): True
# Power Watts (GPU): 5.158
# Data Loading Time: 0.0057 seconds
# Sparsity Ratio: 0.0000
# Energy Efficiency (FLOPs/Watt): 126670209.38348196

# %% [markdown]
# ***QUANTIZED TFLITE MODEL RESOURCE UTILISATIONS AND INFERENCE***

# %%
import time
import psutil
import GPUtil
import pynvml



model_paths = [
   f"/mnt/c/modelFiles/10splitsFlatten/quantized_kfold_model_{i}.tflite" for i in range(10) 
]

# Load interpreters
interpreters = [tf.lite.Interpreter(model_path=path) for path in model_paths]
for interpreter in interpreters:
    interpreter.allocate_tensors()
    
#using first model
input_details = interpreters[0].get_input_details() 
output_details = interpreters[0].get_output_details()

# Preprocess image
img_path = "/mnt/c/newTrain/Train/line/17.jpg"
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
img = cv2.resize(img, (256, 256))
img = img.astype(np.float32) / 255.0

# Stack channels
stacked = np.stack([img], axis=-1)

# Quantize input
input_scale, input_zero_point = input_details[0]['quantization']
img_input = stacked / input_scale + input_zero_point
img_input = np.clip(img_input, -128, 127).astype(np.int8)
img_input = np.expand_dims(img_input, axis=0)

# Cold start time (for one model)
t1 = time.time()
interpreters[0].set_tensor(input_details[0]['index'], img_input)
interpreters[0].invoke()
_ = interpreters[0].get_tensor(output_details[0]['index'])
t2 = time.time()
cold_start_time = t2 - t1

# Inference time over 10 trials (ensemble)
times = []
for _ in range(10):
    t1 = time.time()
    predictions = []
    for interpreter in interpreters:
        interpreter.set_tensor(input_details[0]['index'], img_input)
        interpreter.invoke()
        output_data = interpreter.get_tensor(output_details[0]['index'])
        predictions.append(output_data[0])
    _ = np.mean(predictions, axis=0)
    t2 = time.time()
    times.append(t2 - t1)
inference_time = np.mean(times)

# Model size of tflite model 
model_size = os.path.getsize("/mnt/c/modelFiles/10splitsFlatten/quantized_kfold_model_0.tflite") / (1024 * 1024)

# Memory usage
process = psutil.Process(os.getpid())
mem_before = process.memory_info().rss / (1024 * 1024)
for interpreter in interpreters:
    interpreter.set_tensor(input_details[0]['index'], img_input)
    interpreter.invoke()
    _ = interpreter.get_tensor(output_details[0]['index'])
mem_after = process.memory_info().rss / (1024 * 1024)
memory_usage = mem_after - mem_before

# GPU usage
gpus = GPUtil.getGPUs()
gpu_usage = gpus[0].load * 100 if gpus else None

# CPU usage
cpu_util = psutil.cpu_percent(interval=1)

# Power (battery)
try:
    power_usage = psutil.sensors_battery().power_plugged
except:
    power_usage = None

# GPU power
def get_gpu_power():
    pynvml.nvmlInit()
    handle = pynvml.nvmlDeviceGetHandleByIndex(0)
    power = pynvml.nvmlDeviceGetPowerUsage(handle) / 1000
    pynvml.nvmlShutdown()
    return power

power_watts = get_gpu_power()

# Data loading time
t1 = time.time()
_ = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
t2 = time.time()
data_loading_time = t2 - t1

# Print results
print(f"Cold Start Time: {cold_start_time:.4f} s")
print(f"Average Inference Time: {inference_time:.4f} s")
print(f"average Model Size: {model_size:.2f} MB")
print(f"Memory Usage: {memory_usage:.2f} MB")
print(f"GPU Utilization: {gpu_usage:.2f}%" if gpu_usage else "GPU Utilization: Not Available")
print(f"CPU Utilization: {cpu_util:.2f}%")
print(f"Power Plugged In: {power_usage}")
print(f"GPU Power (W): {power_watts}")
print(f"Data Loading Time: {data_loading_time:.4f} s")
# Out:
# Cold Start Time: 0.0186 s
# Average Inference Time: 0.0740 s
# average Model Size: 0.67 MB
# Memory Usage: 0.00 MB
# GPU Utilization: Not Available
# CPU Utilization: 0.50%
# Power Plugged In: True
# GPU Power (W): 4.867
# Data Loading Time: 0.0206 s

# %% [markdown]
# **ENDING CODES**

# %%
# !pip freeze > req.txt
# Out:
# 56423.42s - pydevd: Sending message related to process being replaced timed-out after 5 seconds

# %% [markdown]
# New results 1

# %%
X_test, y_test = [], []
for i in range(len(test_generator)):
    x_batch, y_batch = test_generator[i]
    X_test.append(x_batch)
    y_test.append(y_batch)

X_test = np.vstack(X_test)
y_test = np.vstack(y_test)

# Print shape info
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_test shape: (1195, 256, 256, 1)
# y_test shape: (1195, 5)

# %%
from sklearn.preprocessing import label_binarize
y_test = label_binarize(y_test, classes=range(test_generator.num_classes))

# %%
model1 = tf.keras.models.load_model("/mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_Nokfold_model.keras")
model2 = tf.keras.models.load_model("/mnt/c/modelFiles/10splitsFlatten/greyColor_NoQuant_kfold_model_4.keras")

# %%
y_score = model2.predict(X_test)
print(np.min(y_score), np.max(y_score))
print("Sample predictions:", y_score[:5])
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752074907.907570    2087 service.cc:148] XLA service 0x7f1e9c004100 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1752074907.907952    2087 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2025-07-09 15:28:27.919350: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1752074908.000366    2087 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 32/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# I0000 00:00:1752074910.586910    2087 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step
# 0.0 1.0
# Sample predictions: [[9.9994671e-01 3.5522077e-10 1.6474821e-16 2.2991212e-08 5.3228607e-05]
#  [1.0000000e+00 1.3731415e-10 3.0250848e-19 6.4692231e-11 3.7052381e-08]
#  [9.9999988e-01 5.9132410e-09 4.5848845e-17 7.9366927e-08 5.4090976e-10]
#  [9.9999297e-01 4.0227178e-06 4.8582145e-13 3.0118422e-06 2.8958260e-09]
#  [9.9999905e-01 5.7292069e-09 3.9567780e-15 2.7383069e-07 7.2705689e-07]]

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

def plot_roc_auc_robust(model, X_test, y_test, model_name="Model"):
    y_score = model.predict(X_test)
    n_classes = y_test.shape[1]

    plt.figure(figsize=(8, 6))
    valid = False
    for i in range(n_classes):
        if np.sum(y_test[:, i]) == 0 or np.sum(y_test[:, i]) == len(y_test):
            print(f"Skipping Class {i} — only one class present in ground truth.")
            continue
        fpr, tpr, _ = roc_curve(y_test[:, i], y_score[:, i])
        roc_auc = auc(fpr, tpr)
        if np.isnan(roc_auc): continue
        plt.plot(fpr, tpr, lw=2, label=f'Class {i} (AUC={roc_auc:.2f})')
        valid = True

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"ROC Curve: {model_name}")
    if valid:
        plt.legend(loc='lower right')
    else:
        plt.text(0.3, 0.5, "ROC could not be computed for any class", fontsize=12)
    plt.grid(True)
    plt.show()

plot_roc_auc_robust(model1, X_test, y_test, model_name="greyColor_NoQuant_Nokfold_model")
plot_roc_auc_robust(model2, X_test, y_test, model_name="greyColor_NoQuant_kfold_model")
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
from sklearn.metrics import precision_recall_curve, auc
import matplotlib.pyplot as plt

def plot_pr_auc(model, X_test, y_test, model_name="Model"):
    y_score = model.predict(X_test)
    n_classes = y_test.shape[1]

    plt.figure(figsize=(8, 6))
    for i in range(n_classes):
        precision, recall, _ = precision_recall_curve(y_test[:, i], y_score[:, i])
        pr_auc = auc(recall, precision)
        plt.plot(recall, precision, lw=2, label=f'Class {i} (AUC={pr_auc:.2f})')
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title(f"Precision-Recall Curve: {model_name}")
    plt.legend(loc='lower left')
    plt.grid(True)
    plt.show()

# Example usage
plot_pr_auc(model1, X_test, y_test, "greyColor_NoQuant_Nokfold_model")
plot_pr_auc(model2, X_test, y_test, "greyColor_NoQuant_kfold_model")
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
from sklearn.metrics import log_loss

def compute_log_loss(model, X_test, y_test, model_name="Model"):
    y_prob = model.predict(X_test)
    loss = log_loss(y_test, y_prob)
    print(f"{model_name} Log Loss: {loss:.4f}")

# Example usage
compute_log_loss(model1, X_test, y_test, "Model 1")
compute_log_loss(model2, X_test, y_test, "Model 2")
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Model 1 Log Loss: 0.3091
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Model 2 Log Loss: 0.0460

# %%
def compare_pr_curves(models, model_names, X_test, y_test, class_index=0):
    plt.figure(figsize=(8, 6))
    for model, name in zip(models, model_names):
        y_score = model.predict(X_test)
        precision, recall, _ = precision_recall_curve(y_test[:, class_index], y_score[:, class_index])
        pr_auc = auc(recall, precision)
        plt.plot(recall, precision, lw=2, label=f'{name} (AUC={pr_auc:.2f})')
    
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title(f"Precision-Recall Comparison (Class {class_index})")
    plt.legend(loc='lower left')
    plt.grid(True)
    plt.show()

# Example usage for class 0
compare_pr_curves(
    [model1, model2],
    ["Model 1", "Model 2"],
    X_test, y_test,
    class_index=4
)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
def grad_cam(model, image, class_idx, conv_layer_name=None):
    import tensorflow as tf
    import numpy as np
    import matplotlib.pyplot as plt
    import cv2

    # Force graph initialization
    _ = model(np.expand_dims(image, axis=0), training=False)

    # Automatically find last Conv2D layer if not given
    if conv_layer_name is None:
        for layer in reversed(model.layers):
            if isinstance(layer, tf.keras.layers.Conv2D):
                conv_layer_name = layer.name
                break

    conv_layer = model.get_layer(conv_layer_name)

    # Build grad model
    grad_model = tf.keras.models.Model(
        [model.input], [conv_layer.output, model.output]
    )

    # Gradient calculation
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(np.expand_dims(image, axis=0))
        loss = predictions[:, class_idx]

    grads = tape.gradient(loss, conv_outputs)[0]
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs = conv_outputs[0]
    heatmap = tf.reduce_sum(tf.multiply(pooled_grads, conv_outputs), axis=-1)
    heatmap = np.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-6)
    heatmap = heatmap.numpy()

    # Resize & colorize
    heatmap = cv2.resize(heatmap, (image.shape[1], image.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    heatmap_color = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

    # Normalize input image for overlay
    if np.max(image) <= 1.0:
        image_disp = np.uint8(image * 255)
    else:
        image_disp = np.uint8(image)

    if image_disp.shape[-1] == 1:
        image_disp = np.repeat(image_disp, 3, axis=-1)

    superimposed = heatmap_color * 0.4 + image_disp

    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.imshow(image_disp.squeeze(), cmap='gray')
    plt.title("Original Image")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(superimposed.astype("uint8"))
    plt.title(f"Grad-CAM (Class {class_idx})")
    plt.axis("off")
    plt.tight_layout()
    plt.show()

# %%
import os
from collections import Counter
import matplotlib.pyplot as plt

def count_images_in_class_dirs(base_dir):
    class_counts = Counter()
    for class_name in os.listdir(base_dir):
        class_path = os.path.join(base_dir, class_name)
        if os.path.isdir(class_path):
            num_images = len([
                f for f in os.listdir(class_path)
                if os.path.isfile(os.path.join(class_path, f)) and f.lower().endswith(('.png', '.jpg', '.jpeg'))
            ])
            class_counts[class_name] += num_images
    return class_counts

# Count images from both folders
train_counts = count_images_in_class_dirs(train_dir)
test_counts = count_images_in_class_dirs(test_dir)

# Combine counts
total_counts = train_counts + test_counts

# Sort by class name (optional for neat pie chart)
total_counts = dict(sorted(total_counts.items()))

# Plot pie chart
plt.figure(figsize=(6, 6))
plt.pie(total_counts.values(), labels=total_counts.keys(), autopct='%1.1f%%', startangle=140)
plt.title("Combined Class Distribution")
plt.axis('equal')
plt.tight_layout()
plt.show()
print("Class distribution:", total_counts)
# Out:
# Class distribution: {'No_Defect': 1403, 'horizontal_line': 680, 'stain': 633, 'tear': 1412, 'vertical_line': 672}

# %%
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Get predictions from both models
y_pred1 = model1.predict(X_test)
y_pred2 = model2.predict(X_test)

# Step 2: Convert to class labels
y_pred1_labels = np.argmax(y_pred1, axis=1)
y_pred2_labels = np.argmax(y_pred2, axis=1)
y_true_labels = np.argmax(y_test, axis=1)  # assumes one-hot y_test

# Step 3: Get per-class F1 scores
report1 = classification_report(y_true_labels, y_pred1_labels, output_dict=True, zero_division=0)
report2 = classification_report(y_true_labels, y_pred2_labels, output_dict=True, zero_division=0)

# Step 4: Extract per-class F1 scores
class_labels = sorted([int(k) for k in report1.keys() if k.isdigit()])
f1_scores_1 = [report1[str(cls)]['f1-score'] for cls in class_labels]
f1_scores_2 = [report2[str(cls)]['f1-score'] for cls in class_labels]

# Optional: add class names
class_names = ['No_Defect', 'horizontal_line', 'stain', 'tear', 'vertical_line']

# Step 5: Plotting
x = np.arange(len(class_labels))
width = 0.35

plt.figure(figsize=(10, 5))
plt.bar(x - width/2, f1_scores_1, width, label='Model 1', color='steelblue')
plt.bar(x + width/2, f1_scores_2, width, label='Model 2', color='orange')

plt.xticks(x, class_names, rotation=45)
plt.ylabel('F1 Score')
plt.title('Per-Class F1 Score Comparison')
plt.ylim(0, 1.1)
plt.legend()
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
